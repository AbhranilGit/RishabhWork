# %%
import requests
import json
import time
from datetime import datetime
import pandas as pd
import os

class GroundhoggAPI:
    def __init__(self, site_url, token, public_key):
        """
        Initialize the Groundhogg API client
        
        Args:
            site_url (str): Your WordPress site URL (e.g., https://example.com)
            token (str): Your Groundhogg API token
            public_key (str): Your Groundhogg public key
        """
        self.base_url = f"{site_url.rstrip('/')}/wp-json/gh/v4"
        self.token = token
        self.public_key = public_key
        self.headers = {
            "Gh-Token": self.token,
            "Gh-Public-Key": self.public_key
        }
        
    def _make_request(self, endpoint, method="GET", params=None, data=None):
        """Make an API request to Groundhogg"""
        url = f"{self.base_url}/{endpoint.lstrip('/')}"
        
        try:
            if method.upper() == "GET":
                response = requests.get(url, headers=self.headers, params=params)
            elif method.upper() == "POST":
                response = requests.post(url, headers=self.headers, json=data, params=params)
            elif method.upper() == "PUT":
                response = requests.put(url, headers=self.headers, json=data, params=params)
            elif method.upper() == "DELETE":
                response = requests.delete(url, headers=self.headers, params=params)
            else:
                raise ValueError(f"Unsupported HTTP method: {method}")
            
            response.raise_for_status()  # Raise exception for HTTP errors
            return response.json()
        
        except requests.exceptions.RequestException as e:
            print(f"API request error: {e}")
            return None
    
    def get_contacts(self, page=1, per_page=100):
        """
        Get contacts from Groundhogg
        
        Args:
            page (int): Page number for pagination
            per_page (int): Number of contacts per page
            
        Returns:
            dict: JSON response containing contacts
        """
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/contacts', params=params)
    
    def get_all_contacts(self):
        """
        Get all contacts from Groundhogg by paginating through results
        
        Returns:
            list: List of all contacts
        """
        all_contacts = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_contacts(page=page, per_page=per_page)
            
            if not response or 'contacts' not in response or not response['contacts']:
                break
                
            all_contacts.extend(response['contacts'])
            
            if len(response['contacts']) < per_page:
                break
                
            page += 1
            time.sleep(1)  # Avoid hitting rate limits
        
        return all_contacts
    
    def get_tags(self, page=1, per_page=100):
        """Get all tags"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/tags', params=params)
    
    def get_all_tags(self):
        """Get all tags by paginating through results"""
        all_tags = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_tags(page=page, per_page=per_page)
            
            if not response or 'tags' not in response or not response['tags']:
                break
                
            all_tags.extend(response['tags'])
            
            if len(response['tags']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_tags
    
    def get_contact_meta(self, contact_id):
        """Get metadata for a specific contact"""
        return self._make_request(f'/contacts/{contact_id}/meta')
    
    def get_funnels(self):
        """Get all funnels"""
        return self._make_request('/funnels')
    
    def get_funnel_steps(self, funnel_id):
        """Get steps for a specific funnel"""
        return self._make_request(f'/funnels/{funnel_id}/steps')
    
    def get_events(self, page=1, per_page=100):
        """Get contact events"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/events', params=params)
    
    def get_all_events(self):
        """Get all events by paginating through results"""
        all_events = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_events(page=page, per_page=per_page)
            
            if not response or 'events' not in response or not response['events']:
                break
                
            all_events.extend(response['events'])
            
            if len(response['events']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_events
    
    def export_data_to_csv(self, data_type, file_name=None):
        """
        Export data to CSV file
        
        Args:
            data_type (str): Type of data to export (contacts, tags, events)
            file_name (str, optional): Custom file name
            
        Returns:
            str: Path to the saved CSV file
        """
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        
        if not file_name:
            file_name = f"groundhogg_{data_type}_{timestamp}.csv"
        
        data = []
        
        if data_type == 'contacts':
            data = self.get_all_contacts()
        elif data_type == 'tags':
            data = self.get_all_tags()
        elif data_type == 'events':
            data = self.get_all_events()
        else:
            raise ValueError(f"Unsupported data type: {data_type}")
        
        if not data:
            print(f"No {data_type} data found to export")
            return None
        
        df = pd.DataFrame(data)
        df.to_csv(file_name, index=False)
        
        print(f"Exported {len(data)} {data_type} to {file_name}")
        return file_name


def main():
    """Main function to run the script"""
    # Replace these with your actual credentials
    site_url = "https://scholistico.com"
    token = "26a0293b0a4da82a960e6eb9effb4e31"
    public_key = "0bc1ccfccb63183f99cbf2620847b64f"
    
    # Check if credentials are provided
    if token == "your_groundhogg_token" or public_key == "your_groundhogg_public_key":
        print("Please update the script with your actual API credentials.")
        return
    
    # Initialize the API client
    api = GroundhoggAPI(site_url, token, public_key)
    
    # Create directory for exports
    export_dir = "groundhogg_exports"
    os.makedirs(export_dir, exist_ok=True)
    os.chdir(export_dir)
    
    # Test the API connection
    print("Testing API connection...")
    test_response = api.get_contacts(page=1, per_page=1)
    if not test_response:
        print("Could not connect to the Groundhogg API. Please check your credentials and try again.")
        return
    
    print("API connection successful!")
    
    # Export all data types
    print("Starting data export from Groundhogg...")
    
    # Export contacts
    api.export_data_to_csv("contacts")
    
    # Export tags
    api.export_data_to_csv("tags")
    
    # Export events
    api.export_data_to_csv("events")
    
    print(f"All data exported to directory: {export_dir}")


if __name__ == "__main__":
    main()
# Out:
# Testing API connection...
# API connection successful!
# Starting data export from Groundhogg...
# No contacts data found to export
# No tags data found to export
# No events data found to export
# All data exported to directory: groundhogg_exports

# %%
import requests
import json
import time
from datetime import datetime
import pandas as pd
import os

class GroundhoggAPI:
    def __init__(self, site_url, token, public_key):
        """
        Initialize the Groundhogg API client
        
        Args:
            site_url (str): Your WordPress site URL (e.g., https://example.com)
            token (str): Your Groundhogg API token
            public_key (str): Your Groundhogg public key
        """
        self.base_url = f"{site_url.rstrip('/')}/wp-json/gh/v3"
        self.token = token
        self.public_key = public_key
        self.headers = {
            "Gh-Token": self.token,
            "Gh-Public-Key": self.public_key
        }
        
    def _make_request(self, endpoint, method="GET", params=None, data=None):
        """Make an API request to Groundhogg"""
        url = f"{self.base_url}/{endpoint.lstrip('/')}"
        
        try:
            print(f"Making request to: {url}")
            if method.upper() == "GET":
                response = requests.get(url, headers=self.headers, params=params)
            elif method.upper() == "POST":
                response = requests.post(url, headers=self.headers, json=data, params=params)
            elif method.upper() == "PUT":
                response = requests.put(url, headers=self.headers, json=data, params=params)
            elif method.upper() == "DELETE":
                response = requests.delete(url, headers=self.headers, params=params)
            else:
                raise ValueError(f"Unsupported HTTP method: {method}")
            
            response.raise_for_status()  # Raise exception for HTTP errors
            return response.json()
        
        except requests.exceptions.RequestException as e:
            print(f"API request error: {e}")
            if hasattr(e, 'response') and e.response is not None:
                print(f"Response content: {e.response.text}")
            return None
    
    def get_contacts(self, page=1, per_page=100):
        """
        Get contacts from Groundhogg
        
        Args:
            page (int): Page number for pagination
            per_page (int): Number of contacts per page
            
        Returns:
            dict: JSON response containing contacts
        """
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/contacts', params=params)
    
    def get_all_contacts(self):
        """
        Get all contacts from Groundhogg by paginating through results
        
        Returns:
            list: List of all contacts
        """
        all_contacts = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_contacts(page=page, per_page=per_page)
            
            if not response or 'contacts' not in response or not response['contacts']:
                break
                
            all_contacts.extend(response['contacts'])
            
            if len(response['contacts']) < per_page:
                break
                
            page += 1
            time.sleep(1)  # Avoid hitting rate limits
        
        return all_contacts
    
    def get_tags(self, page=1, per_page=100):
        """Get all tags"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/tags', params=params)
    
    def get_all_tags(self):
        """Get all tags by paginating through results"""
        all_tags = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_tags(page=page, per_page=per_page)
            
            if not response or 'tags' not in response or not response['tags']:
                break
                
            all_tags.extend(response['tags'])
            
            if len(response['tags']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_tags
    
    def get_companies(self, page=1, per_page=100):
        """Get all companies"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/companies', params=params)
    
    def get_all_companies(self):
        """Get all companies by paginating through results"""
        all_companies = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_companies(page=page, per_page=per_page)
            
            if not response or 'companies' not in response or not response['companies']:
                break
                
            all_companies.extend(response['companies'])
            
            if len(response['companies']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_companies
    
    def get_funnels(self, page=1, per_page=100):
        """Get all funnels"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/funnels', params=params)
    
    def get_all_funnels(self):
        """Get all funnels by paginating through results"""
        all_funnels = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_funnels(page=page, per_page=per_page)
            
            if not response or 'funnels' not in response or not response['funnels']:
                break
                
            all_funnels.extend(response['funnels'])
            
            if len(response['funnels']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_funnels
    
    def get_broadcasts(self, page=1, per_page=100):
        """Get all broadcasts"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/broadcasts', params=params)
    
    def get_all_broadcasts(self):
        """Get all broadcasts by paginating through results"""
        all_broadcasts = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_broadcasts(page=page, per_page=per_page)
            
            if not response or 'broadcasts' not in response or not response['broadcasts']:
                break
                
            all_broadcasts.extend(response['broadcasts'])
            
            if len(response['broadcasts']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_broadcasts
    
    def get_emails(self, page=1, per_page=100):
        """Get all emails"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/emails', params=params)
    
    def get_all_emails(self):
        """Get all emails by paginating through results"""
        all_emails = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_emails(page=page, per_page=per_page)
            
            if not response or 'emails' not in response or not response['emails']:
                break
                
            all_emails.extend(response['emails'])
            
            if len(response['emails']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_emails
    
    def get_sms(self, page=1, per_page=100):
        """Get all SMS messages"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/sms', params=params)
    
    def get_all_sms(self):
        """Get all SMS messages by paginating through results"""
        all_sms = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_sms(page=page, per_page=per_page)
            
            if not response or 'sms' not in response or not response['sms']:
                break
                
            all_sms.extend(response['sms'])
            
            if len(response['sms']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_sms
    
    def get_campaigns(self, page=1, per_page=100):
        """Get all campaigns"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/campaigns', params=params)
    
    def get_all_campaigns(self):
        """Get all campaigns by paginating through results"""
        all_campaigns = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_campaigns(page=page, per_page=per_page)
            
            if not response or 'campaigns' not in response or not response['campaigns']:
                break
                
            all_campaigns.extend(response['campaigns'])
            
            if len(response['campaigns']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_campaigns
    
    def get_superlinks(self, page=1, per_page=100):
        """Get all superlinks"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/superlinks', params=params)
    
    def get_all_superlinks(self):
        """Get all superlinks by paginating through results"""
        all_superlinks = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_superlinks(page=page, per_page=per_page)
            
            if not response or 'superlinks' not in response or not response['superlinks']:
                break
                
            all_superlinks.extend(response['superlinks'])
            
            if len(response['superlinks']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_superlinks
    
    def get_events(self, page=1, per_page=100):
        """Get contact events"""
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request('/events', params=params)
    
    def get_all_events(self):
        """Get all events by paginating through results"""
        all_events = []
        page = 1
        per_page = 100
        
        while True:
            response = self.get_events(page=page, per_page=per_page)
            
            if not response or 'events' not in response or not response['events']:
                break
                
            all_events.extend(response['events'])
            
            if len(response['events']) < per_page:
                break
                
            page += 1
            time.sleep(1)
        
        return all_events
    
    def export_data_to_csv(self, data_type, file_name=None):
        """
        Export data to CSV file
        
        Args:
            data_type (str): Type of data to export (contacts, tags, events, etc.)
            file_name (str, optional): Custom file name
            
        Returns:
            str: Path to the saved CSV file
        """
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        
        if not file_name:
            file_name = f"groundhogg_{data_type}_{timestamp}.csv"
        
        data = []
        
        # Map data_type to corresponding method
        data_type_method_map = {
            'contacts': self.get_all_contacts,
            'tags': self.get_all_tags,
            'companies': self.get_all_companies,
            'funnels': self.get_all_funnels,
            'broadcasts': self.get_all_broadcasts,
            'emails': self.get_all_emails,
            'sms': self.get_all_sms,
            'campaigns': self.get_all_campaigns,
            'superlinks': self.get_all_superlinks,
            'events': self.get_all_events,
        }
        
        if data_type not in data_type_method_map:
            raise ValueError(f"Unsupported data type: {data_type}")
        
        data = data_type_method_map[data_type]()
        
        if not data:
            print(f"No {data_type} data found to export")
            return None
        
        # Convert to DataFrame and save to CSV
        df = pd.DataFrame(data)
        df.to_csv(file_name, index=False)
        
        print(f"Exported {len(data)} {data_type} to {file_name}")
        return file_name


def main():
    """Main function to run the script"""
    # Replace these with your actual credentials
    site_url = "https://scholistico.com"
    token = "26a0293b0a4da82a960e6eb9effb4e31"
    public_key = "0bc1ccfccb63183f99cbf2620847b64f"
    
    # Check if credentials are provided
    if token == "your_groundhogg_token" or public_key == "your_groundhogg_public_key":
        print("Please update the script with your actual API credentials.")
        return
    
    # Initialize the API client
    api = GroundhoggAPI(site_url, token, public_key)
    
    # Create directory for exports
    export_dir = "groundhogg_exports"
    os.makedirs(export_dir, exist_ok=True)
    os.chdir(export_dir)
    
    # Test the API connection
    print("Testing API connection...")
    test_response = api.get_contacts(page=1, per_page=1)
    if not test_response:
        print("Could not connect to the Groundhogg API. Please check your credentials and try again.")
        return
    
    print("API connection successful!")
    
    # List of all data types to export
    data_types = [
        'contacts',
        'tags',
        'companies',
        'funnels',
        'broadcasts',
        'emails',
        'sms',
        'campaigns',
        'superlinks'
    ]
    
    # Export all data types
    print("Starting data export from Groundhogg...")
    
    for data_type in data_types:
        print(f"\nExporting {data_type}...")
        try:
            api.export_data_to_csv(data_type)
        except Exception as e:
            print(f"Error exporting {data_type}: {e}")
    
    print(f"\nAll data exported to directory: {export_dir}")


if __name__ == "__main__":
    main()
# Out:
# Testing API connection...
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# API connection successful!
# Starting data export from Groundhogg...
#
# Exporting contacts...
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# API request error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Exported 1000 contacts to groundhogg_contacts_20250225_133606.csv
#
# Exporting tags...
# Making request to: https://scholistico.com/wp-json/gh/v3/tags
# API request error: Response ended prematurely
# No tags data found to export
#
# Exporting companies...
# Making request to: https://scholistico.com/wp-json/gh/v3/companies
# API request error: 404 Client Error: Not Found for url: https://scholistico.com/wp-json/gh/v3/companies?page=1&per_page=100
# Response content: {"code":"rest_no_route","message":"No route was found matching the URL and request method.","data":{"status":404}}
# No companies data found to export
#
# Exporting funnels...
# Making request to: https://scholistico.com/wp-json/gh/v3/funnels
# API request error: 404 Client Error: Not Found for url: https://scholistico.com/wp-json/gh/v3/funnels?page=1&per_page=100
# Response content: {"code":"rest_no_route","message":"No route was found matching the URL and request method.","data":{"status":404}}
# No funnels data found to export
#
# Exporting broadcasts...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# API request error: HTTPSConnectionPool(host='scholistico.com', port=443): Read timed out. (read timeout=None)
# Exported 13640 broadcasts to groundhogg_broadcasts_20250225_133710.csv
#
# Exporting emails...
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# Making request to: https://scholistico.com/wp-json/gh/v3/emails
# API request error: Response ended prematurely
# Exported 16137 emails to groundhogg_emails_20250225_140407.csv
#
# Exporting sms...
# Making request to: https://scholistico.com/wp-json/gh/v3/sms
# Exported 23 sms to groundhogg_sms_20250225_140712.csv
#
# Exporting campaigns...
# Making request to: https://scholistico.com/wp-json/gh/v3/campaigns
# API request error: 404 Client Error: Not Found for url: https://scholistico.com/wp-json/gh/v3/campaigns?page=1&per_page=100
# Response content: {"code":"rest_no_route","message":"No route was found matching the URL and request method.","data":{"status":404}}
# No campaigns data found to export
#
# Exporting superlinks...
# Making request to: https://scholistico.com/wp-json/gh/v3/superlinks
# API request error: 404 Client Error: Not Found for url: https://scholistico.com/wp-json/gh/v3/superlinks?page=1&per_page=100
# Response content: {"code":"rest_no_route","message":"No route was found matching the URL and request method.","data":{"status":404}}
# No superlinks data found to export
#
# All data exported to directory: groundhogg_exports

# %%
expot all 
1) contacts - GET /wp-json/gh/v3/tags
2) Tags
3) companies
4) funnels
5) broadcasts
6) Emails
7) SMS
8) campaigns
9) superlinks

# %%
import requests
import json
import time
from datetime import datetime
import pandas as pd
import os
import sys

class GroundhoggAPI:
    def __init__(self, site_url, token, public_key):
        """
        Initialize the Groundhogg API client
        
        Args:
            site_url (str): Your WordPress site URL (e.g., https://example.com)
            token (str): Your Groundhogg API token
            public_key (str): Your Groundhogg public key
        """
        self.base_url = f"{site_url.rstrip('/')}/wp-json/gh/v3"
        self.token = token
        self.public_key = public_key
        self.headers = {
            "Gh-Token": self.token,
            "Gh-Public-Key": self.public_key
        }
        
    def _make_request(self, endpoint, method="GET", params=None, data=None):
        """Make an API request to Groundhogg"""
        url = f"{self.base_url}/{endpoint.lstrip('/')}"
        
        try:
            print(f"Making request to: {url}")
            
            if method.upper() == "GET":
                response = requests.get(url, headers=self.headers, params=params)
            elif method.upper() == "POST":
                response = requests.post(url, headers=self.headers, json=data, params=params)
            elif method.upper() == "PUT":
                response = requests.put(url, headers=self.headers, json=data, params=params)
            elif method.upper() == "DELETE":
                response = requests.delete(url, headers=self.headers, params=params)
            else:
                raise ValueError(f"Unsupported HTTP method: {method}")
            
            if response.status_code == 404:
                print(f"Resource not found at: {url}")
                return None
                
            response.raise_for_status()  # Raise exception for HTTP errors
            return response.json()
        
        except requests.exceptions.RequestException as e:
            print(f"API request error: {e}")
            return None
    
    def get_count(self, data_type):
        """
        Get total count of items for a specific data type
        
        Args:
            data_type (str): Type of data (contacts, tags, broadcasts, emails, sms)
            
        Returns:
            int: Total count or 0 if unavailable
        """
        endpoint = f'/{data_type}/count'
        response = self._make_request(endpoint)
        
        if response and 'count' in response:
            return response['count']
        return 0
    
    def get_items(self, data_type, page=1, per_page=100):
        """
        Get items of a specific type with pagination
        
        Args:
            data_type (str): Type of data (contacts, tags, broadcasts, emails, sms)
            page (int): Page number for pagination
            per_page (int): Number of items per page
            
        Returns:
            dict: JSON response containing items
        """
        params = {
            'page': page,
            'per_page': per_page
        }
        return self._make_request(f'/{data_type}', params=params)
    
    def get_all_items(self, data_type, report_progress=True):
        """
        Get all items of a specific type by paginating through results
        
        Args:
            data_type (str): Type of data (contacts, tags, broadcasts, emails, sms)
            report_progress (bool): Whether to print progress to console
            
        Returns:
            list: List of all items
            int: Total items fetched
            int: Total items in the system
        """
        all_items = []
        page = 1
        per_page = 100
        key_name = data_type  # Default key name in response
        
        # Different endpoints return different JSON structures
        if data_type == 'broadcasts':
            key_name = 'broadcasts'
        elif data_type == 'emails':
            key_name = 'emails'
        elif data_type == 'sms':
            key_name = 'messages'
        
        # Get total count
        total_count = self.get_count(data_type)
        if report_progress:
            print(f"Found {total_count} total {data_type} to fetch")
        
        while True:
            if report_progress:
                print(f"Fetching {data_type} - page {page}...")
                
            response = self.get_items(data_type, page=page, per_page=per_page)
            
            if not response or key_name not in response or not response[key_name]:
                break
                
            items_in_page = response[key_name]
            all_items.extend(items_in_page)
            
            if report_progress:
                print(f"Fetched {len(all_items)} of {total_count} {data_type}")
            
            if len(items_in_page) < per_page:
                break
                
            page += 1
            time.sleep(0.5)  # Avoid hitting rate limits
        
        return all_items, len(all_items), total_count
    
    def export_data_to_csv(self, data_type, file_name=None):
        """
        Export data to CSV file
        
        Args:
            data_type (str): Type of data to export (contacts, tags, broadcasts, emails, sms)
            file_name (str, optional): Custom file name
            
        Returns:
            str: Path to the saved CSV file
            bool: Whether all items were fetched
        """
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        
        if not file_name:
            file_name = f"groundhogg_{data_type}_{timestamp}.csv"
        
        print(f"\n=== Exporting {data_type} ===")
        
        data, fetched_count, total_count = self.get_all_items(data_type)
        
        if not data:
            print(f"No {data_type} data found to export")
            return None, False
        
        # Convert to DataFrame and handle nested JSON
        df = pd.json_normalize(data)
        df.to_csv(file_name, index=False)
        
        all_fetched = fetched_count >= total_count
        
        if all_fetched:
            print(f"Success: All {fetched_count} {data_type} fetched and exported to {file_name}")
        else:
            print(f"Warning: {fetched_count} of {total_count} {data_type} fetched and exported to {file_name}. {total_count - fetched_count} pending to fetch.")
        
        return file_name, all_fetched


def main():
    """Main function to run the script"""
    # Replace these with your actual credentials
    site_url = "https://scholistico.com"
    token = "26a0293b0a4da82a960e6eb9effb4e31"
    public_key = "0bc1ccfccb63183f99cbf2620847b64f"
    
    # Check if credentials are provided
    if token == "your_groundhogg_token" or public_key == "your_groundhogg_public_key":
        print("Please update the script with your actual API credentials.")
        return
    
    # Initialize the API client
    api = GroundhoggAPI(site_url, token, public_key)
    
    # Create directory for exports
    export_dir = "groundhogg_exports1"
    os.makedirs(export_dir, exist_ok=True)
    os.chdir(export_dir)
    
    # Test the API connection
    print("Testing API connection...")
    test_response = api.get_items('contacts', page=1, per_page=1)
    if not test_response:
        print("Could not connect to the Groundhogg API. Please check your credentials and try again.")
        return
    
    print("API connection successful!")
    
    # Export all data types
    print("\nStarting data export from Groundhogg...\n")
    
    results = {}
    
    # Define data types to export
    data_types = ['broadcasts', 'emails', 'sms'] # 'contacts', 'tags', 
    
    for data_type in data_types:
        file_path, all_fetched = api.export_data_to_csv(data_type)
        results[data_type] = {
            'file': file_path,
            'all_fetched': all_fetched
        }
    
    # Print summary
    print("\n=== Export Summary ===")
    for data_type, result in results.items():
        status = "All fetched ✓" if result['all_fetched'] else "Incomplete ✗"
        file_info = result['file'] if result['file'] else "Not exported"
        print(f"{data_type.capitalize()}: {status} - {file_info}")
    
    print(f"\nAll data exported to directory: {export_dir}")


if __name__ == "__main__":
    main()
# Out:
# Testing API connection...
# Making request to: https://scholistico.com/wp-json/gh/v3/contacts
# API connection successful!
#
# Starting data export from Groundhogg...
#
#
# === Exporting broadcasts ===
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts/count
# Resource not found at: https://scholistico.com/wp-json/gh/v3/broadcasts/count
# Found 0 total broadcasts to fetch
# Fetching broadcasts - page 1...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 248 of 0 broadcasts
# Fetching broadcasts - page 2...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 496 of 0 broadcasts
# Fetching broadcasts - page 3...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 744 of 0 broadcasts
# Fetching broadcasts - page 4...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 992 of 0 broadcasts
# Fetching broadcasts - page 5...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 1240 of 0 broadcasts
# Fetching broadcasts - page 6...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 1488 of 0 broadcasts
# Fetching broadcasts - page 7...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 1736 of 0 broadcasts
# Fetching broadcasts - page 8...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 1984 of 0 broadcasts
# Fetching broadcasts - page 9...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 2232 of 0 broadcasts
# Fetching broadcasts - page 10...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 2480 of 0 broadcasts
# Fetching broadcasts - page 11...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 2728 of 0 broadcasts
# Fetching broadcasts - page 12...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 2976 of 0 broadcasts
# Fetching broadcasts - page 13...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 3224 of 0 broadcasts
# Fetching broadcasts - page 14...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 3472 of 0 broadcasts
# Fetching broadcasts - page 15...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 3720 of 0 broadcasts
# Fetching broadcasts - page 16...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 3968 of 0 broadcasts
# Fetching broadcasts - page 17...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 4216 of 0 broadcasts
# Fetching broadcasts - page 18...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 4464 of 0 broadcasts
# Fetching broadcasts - page 19...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 4712 of 0 broadcasts
# Fetching broadcasts - page 20...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 4960 of 0 broadcasts
# Fetching broadcasts - page 21...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 5208 of 0 broadcasts
# Fetching broadcasts - page 22...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 5456 of 0 broadcasts
# Fetching broadcasts - page 23...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 5704 of 0 broadcasts
# Fetching broadcasts - page 24...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 5952 of 0 broadcasts
# Fetching broadcasts - page 25...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 6200 of 0 broadcasts
# Fetching broadcasts - page 26...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 6448 of 0 broadcasts
# Fetching broadcasts - page 27...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 6696 of 0 broadcasts
# Fetching broadcasts - page 28...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 6944 of 0 broadcasts
# Fetching broadcasts - page 29...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 7192 of 0 broadcasts
# Fetching broadcasts - page 30...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 7440 of 0 broadcasts
# Fetching broadcasts - page 31...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 7688 of 0 broadcasts
# Fetching broadcasts - page 32...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 7936 of 0 broadcasts
# Fetching broadcasts - page 33...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 8184 of 0 broadcasts
# Fetching broadcasts - page 34...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 8432 of 0 broadcasts
# Fetching broadcasts - page 35...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 8680 of 0 broadcasts
# Fetching broadcasts - page 36...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 8928 of 0 broadcasts
# Fetching broadcasts - page 37...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 9176 of 0 broadcasts
# Fetching broadcasts - page 38...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 9424 of 0 broadcasts
# Fetching broadcasts - page 39...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 9672 of 0 broadcasts
# Fetching broadcasts - page 40...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 9920 of 0 broadcasts
# Fetching broadcasts - page 41...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 10168 of 0 broadcasts
# Fetching broadcasts - page 42...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 10416 of 0 broadcasts
# Fetching broadcasts - page 43...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 10664 of 0 broadcasts
# Fetching broadcasts - page 44...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 10912 of 0 broadcasts
# Fetching broadcasts - page 45...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 11160 of 0 broadcasts
# Fetching broadcasts - page 46...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 11408 of 0 broadcasts
# Fetching broadcasts - page 47...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 11656 of 0 broadcasts
# Fetching broadcasts - page 48...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 11904 of 0 broadcasts
# Fetching broadcasts - page 49...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 12152 of 0 broadcasts
# Fetching broadcasts - page 50...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 12400 of 0 broadcasts
# Fetching broadcasts - page 51...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 12648 of 0 broadcasts
# Fetching broadcasts - page 52...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 12896 of 0 broadcasts
# Fetching broadcasts - page 53...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 13144 of 0 broadcasts
# Fetching broadcasts - page 54...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 13392 of 0 broadcasts
# Fetching broadcasts - page 55...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 13640 of 0 broadcasts
# Fetching broadcasts - page 56...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 13888 of 0 broadcasts
# Fetching broadcasts - page 57...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 14136 of 0 broadcasts
# Fetching broadcasts - page 58...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 14384 of 0 broadcasts
# Fetching broadcasts - page 59...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 14632 of 0 broadcasts
# Fetching broadcasts - page 60...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 14880 of 0 broadcasts
# Fetching broadcasts - page 61...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 15128 of 0 broadcasts
# Fetching broadcasts - page 62...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 15376 of 0 broadcasts
# Fetching broadcasts - page 63...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 15624 of 0 broadcasts
# Fetching broadcasts - page 64...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 15872 of 0 broadcasts
# Fetching broadcasts - page 65...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 16120 of 0 broadcasts
# Fetching broadcasts - page 66...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 16368 of 0 broadcasts
# Fetching broadcasts - page 67...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 16616 of 0 broadcasts
# Fetching broadcasts - page 68...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 16864 of 0 broadcasts
# Fetching broadcasts - page 69...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 17112 of 0 broadcasts
# Fetching broadcasts - page 70...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 17360 of 0 broadcasts
# Fetching broadcasts - page 71...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 17608 of 0 broadcasts
# Fetching broadcasts - page 72...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 17856 of 0 broadcasts
# Fetching broadcasts - page 73...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 18104 of 0 broadcasts
# Fetching broadcasts - page 74...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 18352 of 0 broadcasts
# Fetching broadcasts - page 75...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 18600 of 0 broadcasts
# Fetching broadcasts - page 76...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 18848 of 0 broadcasts
# Fetching broadcasts - page 77...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 19096 of 0 broadcasts
# Fetching broadcasts - page 78...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 19344 of 0 broadcasts
# Fetching broadcasts - page 79...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 19592 of 0 broadcasts
# Fetching broadcasts - page 80...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 19840 of 0 broadcasts
# Fetching broadcasts - page 81...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 20088 of 0 broadcasts
# Fetching broadcasts - page 82...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 20336 of 0 broadcasts
# Fetching broadcasts - page 83...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 20584 of 0 broadcasts
# Fetching broadcasts - page 84...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 20832 of 0 broadcasts
# Fetching broadcasts - page 85...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 21080 of 0 broadcasts
# Fetching broadcasts - page 86...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 21328 of 0 broadcasts
# Fetching broadcasts - page 87...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 21576 of 0 broadcasts
# Fetching broadcasts - page 88...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 21824 of 0 broadcasts
# Fetching broadcasts - page 89...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 22072 of 0 broadcasts
# Fetching broadcasts - page 90...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 22320 of 0 broadcasts
# Fetching broadcasts - page 91...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 22568 of 0 broadcasts
# Fetching broadcasts - page 92...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 22816 of 0 broadcasts
# Fetching broadcasts - page 93...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 23064 of 0 broadcasts
# Fetching broadcasts - page 94...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 23312 of 0 broadcasts
# Fetching broadcasts - page 95...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 23560 of 0 broadcasts
# Fetching broadcasts - page 96...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 23808 of 0 broadcasts
# Fetching broadcasts - page 97...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 24056 of 0 broadcasts
# Fetching broadcasts - page 98...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 24304 of 0 broadcasts
# Fetching broadcasts - page 99...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 24552 of 0 broadcasts
# Fetching broadcasts - page 100...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 24800 of 0 broadcasts
# Fetching broadcasts - page 101...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 25048 of 0 broadcasts
# Fetching broadcasts - page 102...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 25296 of 0 broadcasts
# Fetching broadcasts - page 103...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 25544 of 0 broadcasts
# Fetching broadcasts - page 104...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 25792 of 0 broadcasts
# Fetching broadcasts - page 105...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 26040 of 0 broadcasts
# Fetching broadcasts - page 106...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 26288 of 0 broadcasts
# Fetching broadcasts - page 107...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 26536 of 0 broadcasts
# Fetching broadcasts - page 108...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 26784 of 0 broadcasts
# Fetching broadcasts - page 109...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 27032 of 0 broadcasts
# Fetching broadcasts - page 110...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 27280 of 0 broadcasts
# Fetching broadcasts - page 111...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 27528 of 0 broadcasts
# Fetching broadcasts - page 112...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 27776 of 0 broadcasts
# Fetching broadcasts - page 113...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 28024 of 0 broadcasts
# Fetching broadcasts - page 114...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 28272 of 0 broadcasts
# Fetching broadcasts - page 115...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 28520 of 0 broadcasts
# Fetching broadcasts - page 116...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 28768 of 0 broadcasts
# Fetching broadcasts - page 117...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 29016 of 0 broadcasts
# Fetching broadcasts - page 118...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 29264 of 0 broadcasts
# Fetching broadcasts - page 119...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 29512 of 0 broadcasts
# Fetching broadcasts - page 120...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 29760 of 0 broadcasts
# Fetching broadcasts - page 121...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 30008 of 0 broadcasts
# Fetching broadcasts - page 122...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 30256 of 0 broadcasts
# Fetching broadcasts - page 123...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 30504 of 0 broadcasts
# Fetching broadcasts - page 124...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 30752 of 0 broadcasts
# Fetching broadcasts - page 125...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 31000 of 0 broadcasts
# Fetching broadcasts - page 126...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 31248 of 0 broadcasts
# Fetching broadcasts - page 127...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 31496 of 0 broadcasts
# Fetching broadcasts - page 128...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 31744 of 0 broadcasts
# Fetching broadcasts - page 129...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 31992 of 0 broadcasts
# Fetching broadcasts - page 130...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 32240 of 0 broadcasts
# Fetching broadcasts - page 131...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 32488 of 0 broadcasts
# Fetching broadcasts - page 132...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 32736 of 0 broadcasts
# Fetching broadcasts - page 133...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 32984 of 0 broadcasts
# Fetching broadcasts - page 134...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 33232 of 0 broadcasts
# Fetching broadcasts - page 135...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 33480 of 0 broadcasts
# Fetching broadcasts - page 136...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 33728 of 0 broadcasts
# Fetching broadcasts - page 137...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 33976 of 0 broadcasts
# Fetching broadcasts - page 138...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 34224 of 0 broadcasts
# Fetching broadcasts - page 139...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 34472 of 0 broadcasts
# Fetching broadcasts - page 140...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 34720 of 0 broadcasts
# Fetching broadcasts - page 141...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 34968 of 0 broadcasts
# Fetching broadcasts - page 142...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 35216 of 0 broadcasts
# Fetching broadcasts - page 143...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 35464 of 0 broadcasts
# Fetching broadcasts - page 144...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 35712 of 0 broadcasts
# Fetching broadcasts - page 145...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 35960 of 0 broadcasts
# Fetching broadcasts - page 146...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 36208 of 0 broadcasts
# Fetching broadcasts - page 147...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 36456 of 0 broadcasts
# Fetching broadcasts - page 148...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 36704 of 0 broadcasts
# Fetching broadcasts - page 149...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 36952 of 0 broadcasts
# Fetching broadcasts - page 150...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 37200 of 0 broadcasts
# Fetching broadcasts - page 151...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 37448 of 0 broadcasts
# Fetching broadcasts - page 152...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 37696 of 0 broadcasts
# Fetching broadcasts - page 153...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 37944 of 0 broadcasts
# Fetching broadcasts - page 154...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 38192 of 0 broadcasts
# Fetching broadcasts - page 155...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 38440 of 0 broadcasts
# Fetching broadcasts - page 156...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 38688 of 0 broadcasts
# Fetching broadcasts - page 157...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 38936 of 0 broadcasts
# Fetching broadcasts - page 158...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 39184 of 0 broadcasts
# Fetching broadcasts - page 159...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 39432 of 0 broadcasts
# Fetching broadcasts - page 160...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 39680 of 0 broadcasts
# Fetching broadcasts - page 161...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 39928 of 0 broadcasts
# Fetching broadcasts - page 162...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 40176 of 0 broadcasts
# Fetching broadcasts - page 163...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 40424 of 0 broadcasts
# Fetching broadcasts - page 164...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 40672 of 0 broadcasts
# Fetching broadcasts - page 165...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 40920 of 0 broadcasts
# Fetching broadcasts - page 166...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 41168 of 0 broadcasts
# Fetching broadcasts - page 167...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 41416 of 0 broadcasts
# Fetching broadcasts - page 168...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 41664 of 0 broadcasts
# Fetching broadcasts - page 169...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 41912 of 0 broadcasts
# Fetching broadcasts - page 170...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 42160 of 0 broadcasts
# Fetching broadcasts - page 171...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 42408 of 0 broadcasts
# Fetching broadcasts - page 172...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 42656 of 0 broadcasts
# Fetching broadcasts - page 173...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 42904 of 0 broadcasts
# Fetching broadcasts - page 174...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 43152 of 0 broadcasts
# Fetching broadcasts - page 175...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 43400 of 0 broadcasts
# Fetching broadcasts - page 176...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 43648 of 0 broadcasts
# Fetching broadcasts - page 177...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 43896 of 0 broadcasts
# Fetching broadcasts - page 178...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 44144 of 0 broadcasts
# Fetching broadcasts - page 179...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 44392 of 0 broadcasts
# Fetching broadcasts - page 180...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 44640 of 0 broadcasts
# Fetching broadcasts - page 181...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 44888 of 0 broadcasts
# Fetching broadcasts - page 182...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 45136 of 0 broadcasts
# Fetching broadcasts - page 183...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 45384 of 0 broadcasts
# Fetching broadcasts - page 184...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 45632 of 0 broadcasts
# Fetching broadcasts - page 185...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 45880 of 0 broadcasts
# Fetching broadcasts - page 186...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 46128 of 0 broadcasts
# Fetching broadcasts - page 187...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 46376 of 0 broadcasts
# Fetching broadcasts - page 188...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 46624 of 0 broadcasts
# Fetching broadcasts - page 189...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 46872 of 0 broadcasts
# Fetching broadcasts - page 190...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 47120 of 0 broadcasts
# Fetching broadcasts - page 191...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 47368 of 0 broadcasts
# Fetching broadcasts - page 192...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 47616 of 0 broadcasts
# Fetching broadcasts - page 193...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 47864 of 0 broadcasts
# Fetching broadcasts - page 194...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 48112 of 0 broadcasts
# Fetching broadcasts - page 195...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 48360 of 0 broadcasts
# Fetching broadcasts - page 196...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 48608 of 0 broadcasts
# Fetching broadcasts - page 197...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 48856 of 0 broadcasts
# Fetching broadcasts - page 198...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 49104 of 0 broadcasts
# Fetching broadcasts - page 199...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 49352 of 0 broadcasts
# Fetching broadcasts - page 200...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 49600 of 0 broadcasts
# Fetching broadcasts - page 201...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 49848 of 0 broadcasts
# Fetching broadcasts - page 202...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 50096 of 0 broadcasts
# Fetching broadcasts - page 203...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 50344 of 0 broadcasts
# Fetching broadcasts - page 204...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 50592 of 0 broadcasts
# Fetching broadcasts - page 205...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 50840 of 0 broadcasts
# Fetching broadcasts - page 206...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 51088 of 0 broadcasts
# Fetching broadcasts - page 207...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 51336 of 0 broadcasts
# Fetching broadcasts - page 208...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 51584 of 0 broadcasts
# Fetching broadcasts - page 209...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 51832 of 0 broadcasts
# Fetching broadcasts - page 210...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 52080 of 0 broadcasts
# Fetching broadcasts - page 211...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 52328 of 0 broadcasts
# Fetching broadcasts - page 212...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 52576 of 0 broadcasts
# Fetching broadcasts - page 213...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 52824 of 0 broadcasts
# Fetching broadcasts - page 214...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 53072 of 0 broadcasts
# Fetching broadcasts - page 215...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 53320 of 0 broadcasts
# Fetching broadcasts - page 216...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 53568 of 0 broadcasts
# Fetching broadcasts - page 217...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 53816 of 0 broadcasts
# Fetching broadcasts - page 218...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 54064 of 0 broadcasts
# Fetching broadcasts - page 219...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 54312 of 0 broadcasts
# Fetching broadcasts - page 220...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 54560 of 0 broadcasts
# Fetching broadcasts - page 221...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 54808 of 0 broadcasts
# Fetching broadcasts - page 222...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 55056 of 0 broadcasts
# Fetching broadcasts - page 223...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 55304 of 0 broadcasts
# Fetching broadcasts - page 224...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 55552 of 0 broadcasts
# Fetching broadcasts - page 225...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 55800 of 0 broadcasts
# Fetching broadcasts - page 226...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 56048 of 0 broadcasts
# Fetching broadcasts - page 227...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 56296 of 0 broadcasts
# Fetching broadcasts - page 228...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 56544 of 0 broadcasts
# Fetching broadcasts - page 229...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 56792 of 0 broadcasts
# Fetching broadcasts - page 230...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 57040 of 0 broadcasts
# Fetching broadcasts - page 231...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# Fetched 57288 of 0 broadcasts
# Fetching broadcasts - page 232...
# Making request to: https://scholistico.com/wp-json/gh/v3/broadcasts
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 239
#     235     print(f"\nAll data exported to directory: {export_dir}")
#     238 if __name__ == "__main__":
# --> 239     main()
#
# Cell In[5], line 222, in main()
#     219 data_types = ['broadcasts', 'emails', 'sms'] # 'contacts', 'tags',
#     221 for data_type in data_types:
# --> 222     file_path, all_fetched = api.export_data_to_csv(data_type)
#     223     results[data_type] = {
#     224         'file': file_path,
#     225         'all_fetched': all_fetched
#     226     }
#     228 # Print summary
#
# Cell In[5], line 164, in GroundhoggAPI.export_data_to_csv(self, data_type, file_name)
#     160     file_name = f"groundhogg_{data_type}_{timestamp}.csv"
#     162 print(f"\n=== Exporting {data_type} ===")
# --> 164 data, fetched_count, total_count = self.get_all_items(data_type)
#     166 if not data:
#     167     print(f"No {data_type} data found to export")
#
# Cell In[5], line 126, in GroundhoggAPI.get_all_items(self, data_type, report_progress)
#     123 if report_progress:
#     124     print(f"Fetching {data_type} - page {page}...")
# --> 126 response = self.get_items(data_type, page=page, per_page=per_page)
#     128 if not response or key_name not in response or not response[key_name]:
#     129     break
#
# Cell In[5], line 89, in GroundhoggAPI.get_items(self, data_type, page, per_page)
#      74 """
#      75 Get items of a specific type with pagination
#      76
#    (...)
#      83     dict: JSON response containing items
#      84 """
#      85 params = {
#      86     'page': page,
#      87     'per_page': per_page
#      88 }
# ---> 89 return self._make_request(f'/{data_type}', params=params)
#
# Cell In[5], line 35, in GroundhoggAPI._make_request(self, endpoint, method, params, data)
#      32 print(f"Making request to: {url}")
#      34 if method.upper() == "GET":
# ---> 35     response = requests.get(url, headers=self.headers, params=params)
#      36 elif method.upper() == "POST":
#      37     response = requests.post(url, headers=self.headers, json=data, params=params)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# ?token=26a0293b0a4da82a960e6eb9effb4e31&public_key=0bc1ccfccb63183f99cbf2620847b64f    


token = "26a0293b0a4da82a960e6eb9effb4e31"
    public_key = "0bc1ccfccb63183f99cbf2620847b64f"

# %%
import requests
import pandas as pd
import time
import os

# API Authentication details
SITE_URL = "http://scholistico.com"
TOKEN = "26a0293b0a4da82a960e6eb9effb4e31"  # Replace with your actual token
PUBLIC_KEY = "0bc1ccfccb63183f99cbf2620847b64f"  # Replace with your actual public key

# Headers for authentication
HEADERS = {
    "GH-TOKEN": TOKEN,
    "GH-PUBLIC-KEY": PUBLIC_KEY
}

# Create output directory
os.makedirs("groundhogg_exports", exist_ok=True)

def fetch_all_pages(endpoint, item_key, total_count=None):
    """
    Fetch all pages of data from a paginated API endpoint
    
    Args:
        endpoint (str): API endpoint path
        item_key (str): Key in the response that contains the items
        total_count (int, optional): Expected total count for progress tracking
        
    Returns:
        list: All items from all pages
    """
    url = f"{SITE_URL}/wp-json/gh/v3/{endpoint}"
    all_items = []
    page = 1
    per_page = 100
    
    print(f"Fetching {endpoint}...")
    
    while True:
        params = {"page": page, "per_page": per_page}
        
        try:
            print(f"Fetching page {page}...")
            response = requests.get(url, headers=HEADERS, params=params)
            response.raise_for_status()
            data = response.json()
            
            # Check if we have items in the response
            if item_key not in data or not data[item_key]:
                break
            
            items = data[item_key]
            all_items.extend(items)
            
            # Show progress
            progress = f"Got {len(all_items)} out of {total_count}" if total_count else f"Got {len(all_items)} so far"
            print(f"  {progress}")
            
            # If we got fewer items than requested, we're on the last page
            if len(items) < per_page:
                break
                
            # Move to the next page
            page += 1
            
            # Add a small delay to be respectful to the API
            time.sleep(0.5)
            
        except requests.exceptions.RequestException as e:
            print(f"Error fetching {endpoint}: {e}")
            break
    
    return all_items

def save_to_csv(items, filename):
    """Save items to a CSV file"""
    if not items:
        print(f"No items to save for {filename}")
        return
    
    file_path = f"groundhogg_exports/{filename}.csv"
    
    try:
        df = pd.DataFrame(items)
        df.to_csv(file_path, index=False)
        print(f"Saved {len(items)} items to {file_path}")
    except Exception as e:
        print(f"Error saving {filename}: {e}")

def main():
    print("Starting Groundhogg data export...")
    
    # Check if credentials are provided
    if TOKEN == "YOUR_GH_TOKEN_HERE" or PUBLIC_KEY == "YOUR_GH_PUBLIC_KEY_HERE":
        print("Please update the script with your actual TOKEN and PUBLIC_KEY values.")
        return
    
    # 1. Export Contacts (known total: 166068)
    contacts = fetch_all_pages("contacts", "contacts", 166068)
    save_to_csv(contacts, "contacts")
    
    # 2. Export Tags (known total: 181)
    tags = fetch_all_pages("tags", "tags", 181)
    save_to_csv(tags, "tags")
    
    # 3. Export Broadcasts (known total: 281)
    broadcasts = fetch_all_pages("broadcasts", "broadcasts", 281)
    save_to_csv(broadcasts, "broadcasts")
    
    # 4. Export Emails (known total: 489)
    emails = fetch_all_pages("emails", "emails", 489)
    save_to_csv(emails, "emails")
    
    # 5. Export SMS (known total: 23)
    sms = fetch_all_pages("sms", "sms", 23)
    save_to_csv(sms, "sms")
    
    print("Data export completed!")

if __name__ == "__main__":
    main()
# Out:
# Starting Groundhogg data export...
# Fetching contacts...
# Fetching page 1...
#   Got 100 out of 166068
# Fetching page 2...
#   Got 200 out of 166068
# Fetching page 3...
#   Got 300 out of 166068
# Fetching page 4...
#   Got 400 out of 166068
# Fetching page 5...
#   Got 500 out of 166068
# Fetching page 6...
#   Got 600 out of 166068
# Fetching page 7...
#   Got 700 out of 166068
# Fetching page 8...
#   Got 800 out of 166068
# Fetching page 9...
#   Got 900 out of 166068
# Fetching page 10...
#   Got 1000 out of 166068
# Fetching page 11...
#   Got 1100 out of 166068
# Fetching page 12...
#   Got 1200 out of 166068
# Fetching page 13...
#   Got 1300 out of 166068
# Fetching page 14...
#   Got 1400 out of 166068
# Fetching page 15...
#   Got 1500 out of 166068
# Fetching page 16...
#   Got 1600 out of 166068
# Fetching page 17...
#   Got 1700 out of 166068
# Fetching page 18...
#   Got 1800 out of 166068
# Fetching page 19...
#   Got 1900 out of 166068
# Fetching page 20...
#   Got 2000 out of 166068
# Fetching page 21...
#   Got 2100 out of 166068
# Fetching page 22...
#   Got 2200 out of 166068
# Fetching page 23...
#   Got 2300 out of 166068
# Fetching page 24...
#   Got 2400 out of 166068
# Fetching page 25...
#   Got 2500 out of 166068
# Fetching page 26...
#   Got 2600 out of 166068
# Fetching page 27...
#   Got 2700 out of 166068
# Fetching page 28...
#   Got 2800 out of 166068
# Fetching page 29...
#   Got 2900 out of 166068
# Fetching page 30...
#   Got 3000 out of 166068
# Fetching page 31...
#   Got 3100 out of 166068
# Fetching page 32...
#   Got 3200 out of 166068
# Fetching page 33...
#   Got 3300 out of 166068
# Fetching page 34...
#   Got 3400 out of 166068
# Fetching page 35...
#   Got 3500 out of 166068
# Fetching page 36...
#   Got 3600 out of 166068
# Fetching page 37...
#   Got 3700 out of 166068
# Fetching page 38...
#   Got 3800 out of 166068
# Fetching page 39...
#   Got 3900 out of 166068
# Fetching page 40...
#   Got 4000 out of 166068
# Fetching page 41...
#   Got 4100 out of 166068
# Fetching page 42...
#   Got 4200 out of 166068
# Fetching page 43...
#   Got 4300 out of 166068
# Fetching page 44...
#   Got 4400 out of 166068
# Fetching page 45...
#   Got 4500 out of 166068
# Fetching page 46...
#   Got 4600 out of 166068
# Fetching page 47...
#   Got 4700 out of 166068
# Fetching page 48...
#   Got 4800 out of 166068
# Fetching page 49...
#   Got 4900 out of 166068
# Fetching page 50...
#   Got 5000 out of 166068
# Fetching page 51...
#   Got 5100 out of 166068
# Fetching page 52...
#   Got 5200 out of 166068
# Fetching page 53...
#   Got 5300 out of 166068
# Fetching page 54...
#   Got 5400 out of 166068
# Fetching page 55...
#   Got 5500 out of 166068
# Fetching page 56...
#   Got 5600 out of 166068
# Fetching page 57...
#   Got 5700 out of 166068
# Fetching page 58...
#   Got 5800 out of 166068
# Fetching page 59...
#   Got 5900 out of 166068
# Fetching page 60...
#   Got 6000 out of 166068
# Fetching page 61...
#   Got 6100 out of 166068
# Fetching page 62...
#   Got 6200 out of 166068
# Fetching page 63...
#   Got 6300 out of 166068
# Fetching page 64...
#   Got 6400 out of 166068
# Fetching page 65...
#   Got 6500 out of 166068
# Fetching page 66...
#   Got 6600 out of 166068
# Fetching page 67...
#   Got 6700 out of 166068
# Fetching page 68...
#   Got 6800 out of 166068
# Fetching page 69...
#   Got 6900 out of 166068
# Fetching page 70...
#   Got 7000 out of 166068
# Fetching page 71...
#   Got 7100 out of 166068
# Fetching page 72...
#   Got 7200 out of 166068
# Fetching page 73...
#   Got 7300 out of 166068
# Fetching page 74...
#   Got 7400 out of 166068
# Fetching page 75...
#   Got 7500 out of 166068
# Fetching page 76...
#   Got 7600 out of 166068
# Fetching page 77...
#   Got 7700 out of 166068
# Fetching page 78...
#   Got 7800 out of 166068
# Fetching page 79...
#   Got 7900 out of 166068
# Fetching page 80...
#   Got 8000 out of 166068
# Fetching page 81...
#   Got 8100 out of 166068
# Fetching page 82...
#   Got 8200 out of 166068
# Fetching page 83...
#   Got 8300 out of 166068
# Fetching page 84...
#   Got 8400 out of 166068
# Fetching page 85...
#   Got 8500 out of 166068
# Fetching page 86...
#   Got 8600 out of 166068
# Fetching page 87...
#   Got 8700 out of 166068
# Fetching page 88...
#   Got 8800 out of 166068
# Fetching page 89...
#   Got 8900 out of 166068
# Fetching page 90...
#   Got 9000 out of 166068
# Fetching page 91...
#   Got 9100 out of 166068
# Fetching page 92...
#   Got 9200 out of 166068
# Fetching page 93...
#   Got 9300 out of 166068
# Fetching page 94...
#   Got 9400 out of 166068
# Fetching page 95...
#   Got 9500 out of 166068
# Fetching page 96...
#   Got 9600 out of 166068
# Fetching page 97...
#   Got 9700 out of 166068
# Fetching page 98...
#   Got 9800 out of 166068
# Fetching page 99...
#   Got 9900 out of 166068
# Fetching page 100...
#   Got 10000 out of 166068
# Fetching page 101...
#   Got 10100 out of 166068
# Fetching page 102...
#   Got 10200 out of 166068
# Fetching page 103...
#   Got 10300 out of 166068
# Fetching page 104...
#   Got 10400 out of 166068
# Fetching page 105...
#   Got 10500 out of 166068
# Fetching page 106...
#   Got 10600 out of 166068
# Fetching page 107...
#   Got 10700 out of 166068
# Fetching page 108...
#   Got 10800 out of 166068
# Fetching page 109...
#   Got 10900 out of 166068
# Fetching page 110...
#   Got 11000 out of 166068
# Fetching page 111...
#   Got 11100 out of 166068
# Fetching page 112...
#   Got 11200 out of 166068
# Fetching page 113...
#   Got 11300 out of 166068
# Fetching page 114...
#   Got 11400 out of 166068
# Fetching page 115...
#   Got 11500 out of 166068
# Fetching page 116...
#   Got 11600 out of 166068
# Fetching page 117...
#   Got 11700 out of 166068
# Fetching page 118...
#   Got 11800 out of 166068
# Fetching page 119...
#   Got 11900 out of 166068
# Fetching page 120...
#   Got 12000 out of 166068
# Fetching page 121...
#   Got 12100 out of 166068
# Fetching page 122...
#   Got 12200 out of 166068
# Fetching page 123...
#   Got 12300 out of 166068
# Fetching page 124...
#   Got 12400 out of 166068
# Fetching page 125...
#   Got 12500 out of 166068
# Fetching page 126...
#   Got 12600 out of 166068
# Fetching page 127...
#   Got 12700 out of 166068
# Fetching page 128...
#   Got 12800 out of 166068
# Fetching page 129...
#   Got 12900 out of 166068
# Fetching page 130...
#   Got 13000 out of 166068
# Fetching page 131...
#   Got 13100 out of 166068
# Fetching page 132...
#   Got 13200 out of 166068
# Fetching page 133...
#   Got 13300 out of 166068
# Fetching page 134...
#   Got 13400 out of 166068
# Fetching page 135...
#   Got 13500 out of 166068
# Fetching page 136...
#   Got 13600 out of 166068
# Fetching page 137...
#   Got 13700 out of 166068
# Fetching page 138...
#   Got 13800 out of 166068
# Fetching page 139...
#   Got 13900 out of 166068
# Fetching page 140...
#   Got 14000 out of 166068
# Fetching page 141...
#   Got 14100 out of 166068
# Fetching page 142...
#   Got 14200 out of 166068
# Fetching page 143...
#   Got 14300 out of 166068
# Fetching page 144...
#   Got 14400 out of 166068
# Fetching page 145...
#   Got 14500 out of 166068
# Fetching page 146...
#   Got 14600 out of 166068
# Fetching page 147...
#   Got 14700 out of 166068
# Fetching page 148...
#   Got 14800 out of 166068
# Fetching page 149...
#   Got 14900 out of 166068
# Fetching page 150...
#   Got 15000 out of 166068
# Fetching page 151...
#   Got 15100 out of 166068
# Fetching page 152...
#   Got 15200 out of 166068
# Fetching page 153...
#   Got 15300 out of 166068
# Fetching page 154...
#   Got 15400 out of 166068
# Fetching page 155...
#   Got 15500 out of 166068
# Fetching page 156...
#   Got 15600 out of 166068
# Fetching page 157...
#   Got 15700 out of 166068
# Fetching page 158...
#   Got 15800 out of 166068
# Fetching page 159...
#   Got 15900 out of 166068
# Fetching page 160...
#   Got 16000 out of 166068
# Fetching page 161...
#   Got 16100 out of 166068
# Fetching page 162...
#   Got 16200 out of 166068
# Fetching page 163...
#   Got 16300 out of 166068
# Fetching page 164...
#   Got 16400 out of 166068
# Fetching page 165...
#   Got 16500 out of 166068
# Fetching page 166...
#   Got 16600 out of 166068
# Fetching page 167...
#   Got 16700 out of 166068
# Fetching page 168...
#   Got 16800 out of 166068
# Fetching page 169...
#   Got 16900 out of 166068
# Fetching page 170...
#   Got 17000 out of 166068
# Fetching page 171...
#   Got 17100 out of 166068
# Fetching page 172...
#   Got 17200 out of 166068
# Fetching page 173...
#   Got 17300 out of 166068
# Fetching page 174...
#   Got 17400 out of 166068
# Fetching page 175...
#   Got 17500 out of 166068
# Fetching page 176...
#   Got 17600 out of 166068
# Fetching page 177...
#   Got 17700 out of 166068
# Fetching page 178...
#   Got 17800 out of 166068
# Fetching page 179...
#   Got 17900 out of 166068
# Fetching page 180...
#   Got 18000 out of 166068
# Fetching page 181...
#   Got 18100 out of 166068
# Fetching page 182...
#   Got 18200 out of 166068
# Fetching page 183...
#   Got 18300 out of 166068
# Fetching page 184...
#   Got 18400 out of 166068
# Fetching page 185...
#   Got 18500 out of 166068
# Fetching page 186...
#   Got 18600 out of 166068
# Fetching page 187...
#   Got 18700 out of 166068
# Fetching page 188...
#   Got 18800 out of 166068
# Fetching page 189...
#   Got 18900 out of 166068
# Fetching page 190...
#   Got 19000 out of 166068
# Fetching page 191...
#   Got 19100 out of 166068
# Fetching page 192...
#   Got 19200 out of 166068
# Fetching page 193...
#   Got 19300 out of 166068
# Fetching page 194...
#   Got 19400 out of 166068
# Fetching page 195...
#   Got 19500 out of 166068
# Fetching page 196...
#   Got 19600 out of 166068
# Fetching page 197...
#   Got 19700 out of 166068
# Fetching page 198...
#   Got 19800 out of 166068
# Fetching page 199...
#   Got 19900 out of 166068
# Fetching page 200...
#   Got 20000 out of 166068
# Fetching page 201...
#   Got 20100 out of 166068
# Fetching page 202...
#   Got 20200 out of 166068
# Fetching page 203...
#   Got 20300 out of 166068
# Fetching page 204...
#   Got 20400 out of 166068
# Fetching page 205...
#   Got 20500 out of 166068
# Fetching page 206...
#   Got 20600 out of 166068
# Fetching page 207...
#   Got 20700 out of 166068
# Fetching page 208...
#   Got 20800 out of 166068
# Fetching page 209...
#   Got 20900 out of 166068
# Fetching page 210...
#   Got 21000 out of 166068
# Fetching page 211...
#   Got 21100 out of 166068
# Fetching page 212...
#   Got 21200 out of 166068
# Fetching page 213...
#   Got 21300 out of 166068
# Fetching page 214...
#   Got 21400 out of 166068
# Fetching page 215...
#   Got 21500 out of 166068
# Fetching page 216...
#   Got 21600 out of 166068
# Fetching page 217...
#   Got 21700 out of 166068
# Fetching page 218...
#   Got 21800 out of 166068
# Fetching page 219...
#   Got 21900 out of 166068
# Fetching page 220...
#   Got 22000 out of 166068
# Fetching page 221...
#   Got 22100 out of 166068
# Fetching page 222...
#   Got 22200 out of 166068
# Fetching page 223...
#   Got 22300 out of 166068
# Fetching page 224...
#   Got 22400 out of 166068
# Fetching page 225...
#   Got 22500 out of 166068
# Fetching page 226...
#   Got 22600 out of 166068
# Fetching page 227...
#   Got 22700 out of 166068
# Fetching page 228...
#   Got 22800 out of 166068
# Fetching page 229...
#   Got 22900 out of 166068
# Fetching page 230...
#   Got 23000 out of 166068
# Fetching page 231...
#   Got 23100 out of 166068
# Fetching page 232...
#   Got 23200 out of 166068
# Fetching page 233...
#   Got 23300 out of 166068
# Fetching page 234...
#   Got 23400 out of 166068
# Fetching page 235...
#   Got 23500 out of 166068
# Fetching page 236...
#   Got 23600 out of 166068
# Fetching page 237...
#   Got 23700 out of 166068
# Fetching page 238...
#   Got 23800 out of 166068
# Fetching page 239...
#   Got 23900 out of 166068
# Fetching page 240...
#   Got 24000 out of 166068
# Fetching page 241...
#   Got 24100 out of 166068
# Fetching page 242...
#   Got 24200 out of 166068
# Fetching page 243...
#   Got 24300 out of 166068
# Fetching page 244...
#   Got 24400 out of 166068
# Fetching page 245...
#   Got 24500 out of 166068
# Fetching page 246...
#   Got 24600 out of 166068
# Fetching page 247...
#   Got 24700 out of 166068
# Fetching page 248...
#   Got 24800 out of 166068
# Fetching page 249...
#   Got 24900 out of 166068
# Fetching page 250...
#   Got 25000 out of 166068
# Fetching page 251...
#   Got 25100 out of 166068
# Fetching page 252...
#   Got 25200 out of 166068
# Fetching page 253...
#   Got 25300 out of 166068
# Fetching page 254...
#   Got 25400 out of 166068
# Fetching page 255...
#   Got 25500 out of 166068
# Fetching page 256...
#   Got 25600 out of 166068
# Fetching page 257...
#   Got 25700 out of 166068
# Fetching page 258...
#   Got 25800 out of 166068
# Fetching page 259...
#   Got 25900 out of 166068
# Fetching page 260...
#   Got 26000 out of 166068
# Fetching page 261...
#   Got 26100 out of 166068
# Fetching page 262...
#   Got 26200 out of 166068
# Fetching page 263...
#   Got 26300 out of 166068
# Fetching page 264...
#   Got 26400 out of 166068
# Fetching page 265...
#   Got 26500 out of 166068
# Fetching page 266...
#   Got 26600 out of 166068
# Fetching page 267...
#   Got 26700 out of 166068
# Fetching page 268...
#   Got 26800 out of 166068
# Fetching page 269...
#   Got 26900 out of 166068
# Fetching page 270...
#   Got 27000 out of 166068
# Fetching page 271...
#   Got 27100 out of 166068
# Fetching page 272...
#   Got 27200 out of 166068
# Fetching page 273...
#   Got 27300 out of 166068
# Fetching page 274...
#   Got 27400 out of 166068
# Fetching page 275...
#   Got 27500 out of 166068
# Fetching page 276...
#   Got 27600 out of 166068
# Fetching page 277...
#   Got 27700 out of 166068
# Fetching page 278...
#   Got 27800 out of 166068
# Fetching page 279...
#   Got 27900 out of 166068
# Fetching page 280...
#   Got 28000 out of 166068
# Fetching page 281...
#   Got 28100 out of 166068
# Fetching page 282...
#   Got 28200 out of 166068
# Fetching page 283...
#   Got 28300 out of 166068
# Fetching page 284...
#   Got 28400 out of 166068
# Fetching page 285...
#   Got 28500 out of 166068
# Fetching page 286...
#   Got 28600 out of 166068
# Fetching page 287...
#   Got 28700 out of 166068
# Fetching page 288...
#   Got 28800 out of 166068
# Fetching page 289...
#   Got 28900 out of 166068
# Fetching page 290...
#   Got 29000 out of 166068
# Fetching page 291...
#   Got 29100 out of 166068
# Fetching page 292...
#   Got 29200 out of 166068
# Fetching page 293...
#   Got 29300 out of 166068
# Fetching page 294...
#   Got 29400 out of 166068
# Fetching page 295...
#   Got 29500 out of 166068
# Fetching page 296...
#   Got 29600 out of 166068
# Fetching page 297...
#   Got 29700 out of 166068
# Fetching page 298...
#   Got 29800 out of 166068
# Fetching page 299...
#   Got 29900 out of 166068
# Fetching page 300...
#   Got 30000 out of 166068
# Fetching page 301...
#   Got 30100 out of 166068
# Fetching page 302...
#   Got 30200 out of 166068
# Fetching page 303...
#   Got 30300 out of 166068
# Fetching page 304...
#   Got 30400 out of 166068
# Fetching page 305...
#   Got 30500 out of 166068
# Fetching page 306...
#   Got 30600 out of 166068
# Fetching page 307...
#   Got 30700 out of 166068
# Fetching page 308...
#   Got 30800 out of 166068
# Fetching page 309...
#   Got 30900 out of 166068
# Fetching page 310...
#   Got 31000 out of 166068
# Fetching page 311...
#   Got 31100 out of 166068
# Fetching page 312...
#   Got 31200 out of 166068
# Fetching page 313...
#   Got 31300 out of 166068
# Fetching page 314...
#   Got 31400 out of 166068
# Fetching page 315...
#   Got 31500 out of 166068
# Fetching page 316...
#   Got 31600 out of 166068
# Fetching page 317...
#   Got 31700 out of 166068
# Fetching page 318...
#   Got 31800 out of 166068
# Fetching page 319...
#   Got 31900 out of 166068
# Fetching page 320...
#   Got 32000 out of 166068
# Fetching page 321...
#   Got 32100 out of 166068
# Fetching page 322...
#   Got 32200 out of 166068
# Fetching page 323...
#   Got 32300 out of 166068
# Fetching page 324...
#   Got 32400 out of 166068
# Fetching page 325...
#   Got 32500 out of 166068
# Fetching page 326...
#   Got 32600 out of 166068
# Fetching page 327...
#   Got 32700 out of 166068
# Fetching page 328...
#   Got 32800 out of 166068
# Fetching page 329...
#   Got 32900 out of 166068
# Fetching page 330...
#   Got 33000 out of 166068
# Fetching page 331...
#   Got 33100 out of 166068
# Fetching page 332...
#   Got 33200 out of 166068
# Fetching page 333...
#   Got 33300 out of 166068
# Fetching page 334...
#   Got 33400 out of 166068
# Fetching page 335...
#   Got 33500 out of 166068
# Fetching page 336...
#   Got 33600 out of 166068
# Fetching page 337...
#   Got 33700 out of 166068
# Fetching page 338...
#   Got 33800 out of 166068
# Fetching page 339...
#   Got 33900 out of 166068
# Fetching page 340...
#   Got 34000 out of 166068
# Fetching page 341...
#   Got 34100 out of 166068
# Fetching page 342...
#   Got 34200 out of 166068
# Fetching page 343...
#   Got 34300 out of 166068
# Fetching page 344...
#   Got 34400 out of 166068
# Fetching page 345...
#   Got 34500 out of 166068
# Fetching page 346...
#   Got 34600 out of 166068
# Fetching page 347...
#   Got 34700 out of 166068
# Fetching page 348...
#   Got 34800 out of 166068
# Fetching page 349...
#   Got 34900 out of 166068
# Fetching page 350...
#   Got 35000 out of 166068
# Fetching page 351...
#   Got 35100 out of 166068
# Fetching page 352...
#   Got 35200 out of 166068
# Fetching page 353...
#   Got 35300 out of 166068
# Fetching page 354...
#   Got 35400 out of 166068
# Fetching page 355...
#   Got 35500 out of 166068
# Fetching page 356...
#   Got 35600 out of 166068
# Fetching page 357...
#   Got 35700 out of 166068
# Fetching page 358...
#   Got 35800 out of 166068
# Fetching page 359...
#   Got 35900 out of 166068
# Fetching page 360...
#   Got 36000 out of 166068
# Fetching page 361...
#   Got 36100 out of 166068
# Fetching page 362...
#   Got 36200 out of 166068
# Fetching page 363...
#   Got 36300 out of 166068
# Fetching page 364...
#   Got 36400 out of 166068
# Fetching page 365...
#   Got 36500 out of 166068
# Fetching page 366...
#   Got 36600 out of 166068
# Fetching page 367...
#   Got 36700 out of 166068
# Fetching page 368...
#   Got 36800 out of 166068
# Fetching page 369...
#   Got 36900 out of 166068
# Fetching page 370...
#   Got 37000 out of 166068
# Fetching page 371...
#   Got 37100 out of 166068
# Fetching page 372...
#   Got 37200 out of 166068
# Fetching page 373...
#   Got 37300 out of 166068
# Fetching page 374...
#   Got 37400 out of 166068
# Fetching page 375...
#   Got 37500 out of 166068
# Fetching page 376...
#   Got 37600 out of 166068
# Fetching page 377...
#   Got 37700 out of 166068
# Fetching page 378...
#   Got 37800 out of 166068
# Fetching page 379...
#   Got 37900 out of 166068
# Fetching page 380...
#   Got 38000 out of 166068
# Fetching page 381...
#   Got 38100 out of 166068
# Fetching page 382...
#   Got 38200 out of 166068
# Fetching page 383...
#   Got 38300 out of 166068
# Fetching page 384...
#   Got 38400 out of 166068
# Fetching page 385...
#   Got 38500 out of 166068
# Fetching page 386...
#   Got 38600 out of 166068
# Fetching page 387...
#   Got 38700 out of 166068
# Fetching page 388...
#   Got 38800 out of 166068
# Fetching page 389...
#   Got 38900 out of 166068
# Fetching page 390...
#   Got 39000 out of 166068
# Fetching page 391...
#   Got 39100 out of 166068
# Fetching page 392...
#   Got 39200 out of 166068
# Fetching page 393...
#   Got 39300 out of 166068
# Fetching page 394...
#   Got 39400 out of 166068
# Fetching page 395...
#   Got 39500 out of 166068
# Fetching page 396...
#   Got 39600 out of 166068
# Fetching page 397...
#   Got 39700 out of 166068
# Fetching page 398...
#   Got 39800 out of 166068
# Fetching page 399...
#   Got 39900 out of 166068
# Fetching page 400...
#   Got 40000 out of 166068
# Fetching page 401...
#   Got 40100 out of 166068
# Fetching page 402...
#   Got 40200 out of 166068
# Fetching page 403...
#   Got 40300 out of 166068
# Fetching page 404...
#   Got 40400 out of 166068
# Fetching page 405...
#   Got 40500 out of 166068
# Fetching page 406...
#   Got 40600 out of 166068
# Fetching page 407...
#   Got 40700 out of 166068
# Fetching page 408...
#   Got 40800 out of 166068
# Fetching page 409...
#   Got 40900 out of 166068
# Fetching page 410...
#   Got 41000 out of 166068
# Fetching page 411...
#   Got 41100 out of 166068
# Fetching page 412...
#   Got 41200 out of 166068
# Fetching page 413...
#   Got 41300 out of 166068
# Fetching page 414...
#   Got 41400 out of 166068
# Fetching page 415...
#   Got 41500 out of 166068
# Fetching page 416...
#   Got 41600 out of 166068
# Fetching page 417...
#   Got 41700 out of 166068
# Fetching page 418...
#   Got 41800 out of 166068
# Fetching page 419...
#   Got 41900 out of 166068
# Fetching page 420...
#   Got 42000 out of 166068
# Fetching page 421...
#   Got 42100 out of 166068
# Fetching page 422...
#   Got 42200 out of 166068
# Fetching page 423...
#   Got 42300 out of 166068
# Fetching page 424...
#   Got 42400 out of 166068
# Fetching page 425...
#   Got 42500 out of 166068
# Fetching page 426...
#   Got 42600 out of 166068
# Fetching page 427...
#   Got 42700 out of 166068
# Fetching page 428...
#   Got 42800 out of 166068
# Fetching page 429...
#   Got 42900 out of 166068
# Fetching page 430...
#   Got 43000 out of 166068
# Fetching page 431...
#   Got 43100 out of 166068
# Fetching page 432...
#   Got 43200 out of 166068
# Fetching page 433...
#   Got 43300 out of 166068
# Fetching page 434...
#   Got 43400 out of 166068
# Fetching page 435...
#   Got 43500 out of 166068
# Fetching page 436...
#   Got 43600 out of 166068
# Fetching page 437...
#   Got 43700 out of 166068
# Fetching page 438...
#   Got 43800 out of 166068
# Fetching page 439...
#   Got 43900 out of 166068
# Fetching page 440...
#   Got 44000 out of 166068
# Fetching page 441...
#   Got 44100 out of 166068
# Fetching page 442...
#   Got 44200 out of 166068
# Fetching page 443...
#   Got 44300 out of 166068
# Fetching page 444...
#   Got 44400 out of 166068
# Fetching page 445...
#   Got 44500 out of 166068
# Fetching page 446...
#   Got 44600 out of 166068
# Fetching page 447...
#   Got 44700 out of 166068
# Fetching page 448...
#   Got 44800 out of 166068
# Fetching page 449...
#   Got 44900 out of 166068
# Fetching page 450...
#   Got 45000 out of 166068
# Fetching page 451...
#   Got 45100 out of 166068
# Fetching page 452...
#   Got 45200 out of 166068
# Fetching page 453...
#   Got 45300 out of 166068
# Fetching page 454...
#   Got 45400 out of 166068
# Fetching page 455...
#   Got 45500 out of 166068
# Fetching page 456...
#   Got 45600 out of 166068
# Fetching page 457...
#   Got 45700 out of 166068
# Fetching page 458...
#   Got 45800 out of 166068
# Fetching page 459...
#   Got 45900 out of 166068
# Fetching page 460...
#   Got 46000 out of 166068
# Fetching page 461...
#   Got 46100 out of 166068
# Fetching page 462...
#   Got 46200 out of 166068
# Fetching page 463...
#   Got 46300 out of 166068
# Fetching page 464...
#   Got 46400 out of 166068
# Fetching page 465...
#   Got 46500 out of 166068
# Fetching page 466...
#   Got 46600 out of 166068
# Fetching page 467...
#   Got 46700 out of 166068
# Fetching page 468...
#   Got 46800 out of 166068
# Fetching page 469...
#   Got 46900 out of 166068
# Fetching page 470...
#   Got 47000 out of 166068
# Fetching page 471...
#   Got 47100 out of 166068
# Fetching page 472...
#   Got 47200 out of 166068
# Fetching page 473...
#   Got 47300 out of 166068
# Fetching page 474...
#   Got 47400 out of 166068
# Fetching page 475...
#   Got 47500 out of 166068
# Fetching page 476...
#   Got 47600 out of 166068
# Fetching page 477...
#   Got 47700 out of 166068
# Fetching page 478...
#   Got 47800 out of 166068
# Fetching page 479...
#   Got 47900 out of 166068
# Fetching page 480...
#   Got 48000 out of 166068
# Fetching page 481...
#   Got 48100 out of 166068
# Fetching page 482...
#   Got 48200 out of 166068
# Fetching page 483...
#   Got 48300 out of 166068
# Fetching page 484...
#   Got 48400 out of 166068
# Fetching page 485...
#   Got 48500 out of 166068
# Fetching page 486...
#   Got 48600 out of 166068
# Fetching page 487...
#   Got 48700 out of 166068
# Fetching page 488...
#   Got 48800 out of 166068
# Fetching page 489...
#   Got 48900 out of 166068
# Fetching page 490...
#   Got 49000 out of 166068
# Fetching page 491...
#   Got 49100 out of 166068
# Fetching page 492...
#   Got 49200 out of 166068
# Fetching page 493...
#   Got 49300 out of 166068
# Fetching page 494...
#   Got 49400 out of 166068
# Fetching page 495...
#   Got 49500 out of 166068
# Fetching page 496...
#   Got 49600 out of 166068
# Fetching page 497...
#   Got 49700 out of 166068
# Fetching page 498...
#   Got 49800 out of 166068
# Fetching page 499...
#   Got 49900 out of 166068
# Fetching page 500...
#   Got 50000 out of 166068
# Fetching page 501...
#   Got 50100 out of 166068
# Fetching page 502...
#   Got 50200 out of 166068
# Fetching page 503...
#   Got 50300 out of 166068
# Fetching page 504...
#   Got 50400 out of 166068
# Fetching page 505...
#   Got 50500 out of 166068
# Fetching page 506...
#   Got 50600 out of 166068
# Fetching page 507...
#   Got 50700 out of 166068
# Fetching page 508...
#   Got 50800 out of 166068
# Fetching page 509...
#   Got 50900 out of 166068
# Fetching page 510...
#   Got 51000 out of 166068
# Fetching page 511...
#   Got 51100 out of 166068
# Fetching page 512...
#   Got 51200 out of 166068
# Fetching page 513...
#   Got 51300 out of 166068
# Fetching page 514...
#   Got 51400 out of 166068
# Fetching page 515...
#   Got 51500 out of 166068
# Fetching page 516...
#   Got 51600 out of 166068
# Fetching page 517...
#   Got 51700 out of 166068
# Fetching page 518...
#   Got 51800 out of 166068
# Fetching page 519...
#   Got 51900 out of 166068
# Fetching page 520...
#   Got 52000 out of 166068
# Fetching page 521...
#   Got 52100 out of 166068
# Fetching page 522...
#   Got 52200 out of 166068
# Fetching page 523...
#   Got 52300 out of 166068
# Fetching page 524...
#   Got 52400 out of 166068
# Fetching page 525...
#   Got 52500 out of 166068
# Fetching page 526...
#   Got 52600 out of 166068
# Fetching page 527...
#   Got 52700 out of 166068
# Fetching page 528...
#   Got 52800 out of 166068
# Fetching page 529...
#   Got 52900 out of 166068
# Fetching page 530...
#   Got 53000 out of 166068
# Fetching page 531...
#   Got 53100 out of 166068
# Fetching page 532...
#   Got 53200 out of 166068
# Fetching page 533...
#   Got 53300 out of 166068
# Fetching page 534...
#   Got 53400 out of 166068
# Fetching page 535...
#   Got 53500 out of 166068
# Fetching page 536...
#   Got 53600 out of 166068
# Fetching page 537...
#   Got 53700 out of 166068
# Fetching page 538...
#   Got 53800 out of 166068
# Fetching page 539...
#   Got 53900 out of 166068
# Fetching page 540...
# Error fetching contacts: 503 Server Error: Service Unavailable for url: https://scholistico.com/wp-json/gh/v3/contacts?page=540&per_page=100
# Saved 53900 items to groundhogg_exports/contacts.csv
# Fetching tags...
# Fetching page 1...
#   Got 179 out of 181
# Fetching page 2...
#   Got 358 out of 181
# Fetching page 3...
#   Got 537 out of 181
# Fetching page 4...
#   Got 716 out of 181
# Fetching page 5...
#   Got 895 out of 181
# Fetching page 6...
#   Got 1074 out of 181
# Fetching page 7...
#   Got 1253 out of 181
# Fetching page 8...
#   Got 1432 out of 181
# Fetching page 9...
#   Got 1611 out of 181
# Fetching page 10...
#   Got 1790 out of 181
# Fetching page 11...
#   Got 1969 out of 181
# Fetching page 12...
#   Got 2148 out of 181
# Fetching page 13...
#   Got 2327 out of 181
# Fetching page 14...
#   Got 2506 out of 181
# Fetching page 15...
#   Got 2685 out of 181
# Fetching page 16...
#   Got 2864 out of 181
# Fetching page 17...
#   Got 3043 out of 181
# Fetching page 18...
#   Got 3222 out of 181
# Fetching page 19...
#   Got 3401 out of 181
# Fetching page 20...
#   Got 3580 out of 181
# Fetching page 21...
#   Got 3759 out of 181
# Fetching page 22...
#   Got 3938 out of 181
# Fetching page 23...
#   Got 4117 out of 181
# Fetching page 24...
#   Got 4296 out of 181
# Fetching page 25...
#   Got 4475 out of 181
# Fetching page 26...
#   Got 4654 out of 181
# Fetching page 27...
#   Got 4833 out of 181
# Fetching page 28...
#   Got 5012 out of 181
# Fetching page 29...
#   Got 5191 out of 181
# Fetching page 30...
#   Got 5370 out of 181
# Fetching page 31...
#   Got 5549 out of 181
# Fetching page 32...
#   Got 5728 out of 181
# Fetching page 33...
#   Got 5907 out of 181
# Fetching page 34...
#   Got 6086 out of 181
# Fetching page 35...
#   Got 6265 out of 181
# Fetching page 36...
#   Got 6444 out of 181
# Fetching page 37...
#   Got 6623 out of 181
# Fetching page 38...
#   Got 6802 out of 181
# Fetching page 39...
#   Got 6981 out of 181
# Fetching page 40...
#   Got 7160 out of 181
# Fetching page 41...
#   Got 7339 out of 181
# Fetching page 42...
#   Got 7518 out of 181
# Fetching page 43...
#   Got 7697 out of 181
# Fetching page 44...
#   Got 7876 out of 181
# Fetching page 45...
#   Got 8055 out of 181
# Fetching page 46...
#   Got 8234 out of 181
# Fetching page 47...
#   Got 8413 out of 181
# Fetching page 48...
#   Got 8592 out of 181
# Fetching page 49...
#   Got 8771 out of 181
# Fetching page 50...
#   Got 8950 out of 181
# Fetching page 51...
#   Got 9129 out of 181
# Fetching page 52...
#   Got 9308 out of 181
# Fetching page 53...
#   Got 9487 out of 181
# Fetching page 54...
#   Got 9666 out of 181
# Fetching page 55...
#   Got 9845 out of 181
# Fetching page 56...
#   Got 10024 out of 181
# Fetching page 57...
#   Got 10203 out of 181
# Fetching page 58...
#   Got 10382 out of 181
# Fetching page 59...
#   Got 10561 out of 181
# Fetching page 60...
#   Got 10740 out of 181
# Fetching page 61...
#   Got 10919 out of 181
# Fetching page 62...
#   Got 11098 out of 181
# Fetching page 63...
#   Got 11277 out of 181
# Fetching page 64...
#   Got 11456 out of 181
# Fetching page 65...
#   Got 11635 out of 181
# Fetching page 66...
#   Got 11814 out of 181
# Fetching page 67...
#   Got 11993 out of 181
# Fetching page 68...
#   Got 12172 out of 181
# Fetching page 69...
#   Got 12351 out of 181
# Fetching page 70...
#   Got 12530 out of 181
# Fetching page 71...
#   Got 12709 out of 181
# Fetching page 72...
#   Got 12888 out of 181
# Fetching page 73...
#   Got 13067 out of 181
# Fetching page 74...
#   Got 13246 out of 181
# Fetching page 75...
#   Got 13425 out of 181
# Fetching page 76...
#   Got 13604 out of 181
# Fetching page 77...
#   Got 13783 out of 181
# Fetching page 78...
#   Got 13962 out of 181
# Fetching page 79...
#   Got 14141 out of 181
# Fetching page 80...
#   Got 14320 out of 181
# Fetching page 81...
#   Got 14499 out of 181
# Fetching page 82...
#   Got 14678 out of 181
# Fetching page 83...
#   Got 14857 out of 181
# Fetching page 84...
#   Got 15036 out of 181
# Fetching page 85...
#   Got 15215 out of 181
# Fetching page 86...
#   Got 15394 out of 181
# Fetching page 87...
#   Got 15573 out of 181
# Fetching page 88...
#   Got 15752 out of 181
# Fetching page 89...
#   Got 15931 out of 181
# Fetching page 90...
#   Got 16110 out of 181
# Fetching page 91...
#   Got 16289 out of 181
# Fetching page 92...
#   Got 16468 out of 181
# Fetching page 93...
#   Got 16647 out of 181
# Fetching page 94...
#   Got 16826 out of 181
# Fetching page 95...
#   Got 17005 out of 181
# Fetching page 96...
#   Got 17184 out of 181
# Fetching page 97...
#   Got 17363 out of 181
# Fetching page 98...
#   Got 17542 out of 181
# Fetching page 99...
#   Got 17721 out of 181
# Fetching page 100...
#   Got 17900 out of 181
# Fetching page 101...
#   Got 18079 out of 181
# Fetching page 102...
#   Got 18258 out of 181
# Fetching page 103...
#   Got 18437 out of 181
# Fetching page 104...
#   Got 18616 out of 181
# Fetching page 105...
#   Got 18795 out of 181
# Fetching page 106...
#   Got 18974 out of 181
# Fetching page 107...
#   Got 19153 out of 181
# Fetching page 108...
#   Got 19332 out of 181
# Fetching page 109...
#   Got 19511 out of 181
# Fetching page 110...
#   Got 19690 out of 181
# Fetching page 111...
#   Got 19869 out of 181
# Fetching page 112...
#   Got 20048 out of 181
# Fetching page 113...
#   Got 20227 out of 181
# Fetching page 114...
#   Got 20406 out of 181
# Fetching page 115...
#   Got 20585 out of 181
# Fetching page 116...
#   Got 20764 out of 181
# Fetching page 117...
#   Got 20943 out of 181
# Fetching page 118...
#   Got 21122 out of 181
# Fetching page 119...
#   Got 21301 out of 181
# Fetching page 120...
#   Got 21480 out of 181
# Fetching page 121...
#   Got 21659 out of 181
# Fetching page 122...
#   Got 21838 out of 181
# Fetching page 123...
#   Got 22017 out of 181
# Fetching page 124...
#   Got 22196 out of 181
# Fetching page 125...
#   Got 22375 out of 181
# Fetching page 126...
#   Got 22554 out of 181
# Fetching page 127...
#   Got 22733 out of 181
# Fetching page 128...
#   Got 22912 out of 181
# Fetching page 129...
#   Got 23091 out of 181
# Fetching page 130...
#   Got 23270 out of 181
# Fetching page 131...
#   Got 23449 out of 181
# Fetching page 132...
#   Got 23628 out of 181
# Fetching page 133...
#   Got 23807 out of 181
# Fetching page 134...
#   Got 23986 out of 181
# Fetching page 135...
#   Got 24165 out of 181
# Fetching page 136...
#   Got 24344 out of 181
# Fetching page 137...
#   Got 24523 out of 181
# Fetching page 138...
#   Got 24702 out of 181
# Fetching page 139...
#   Got 24881 out of 181
# Fetching page 140...
#   Got 25060 out of 181
# Fetching page 141...
#   Got 25239 out of 181
# Fetching page 142...
#   Got 25418 out of 181
# Fetching page 143...
#   Got 25597 out of 181
# Fetching page 144...
#   Got 25776 out of 181
# Fetching page 145...
#   Got 25955 out of 181
# Fetching page 146...
#   Got 26134 out of 181
# Fetching page 147...
#   Got 26313 out of 181
# Fetching page 148...
#   Got 26492 out of 181
# Fetching page 149...
#   Got 26671 out of 181
# Fetching page 150...
#   Got 26850 out of 181
# Fetching page 151...
#   Got 27029 out of 181
# Fetching page 152...
#   Got 27208 out of 181
# Fetching page 153...
#   Got 27387 out of 181
# Fetching page 154...
#   Got 27566 out of 181
# Fetching page 155...
#   Got 27745 out of 181
# Fetching page 156...
#   Got 27924 out of 181
# Fetching page 157...
#   Got 28103 out of 181
# Fetching page 158...
#   Got 28282 out of 181
# Fetching page 159...
#   Got 28461 out of 181
# Fetching page 160...
#   Got 28640 out of 181
# Fetching page 161...
#   Got 28819 out of 181
# Fetching page 162...
#   Got 28998 out of 181
# Fetching page 163...
#   Got 29177 out of 181
# Fetching page 164...
#   Got 29356 out of 181
# Fetching page 165...
#   Got 29535 out of 181
# Fetching page 166...
#   Got 29714 out of 181
# Fetching page 167...
#   Got 29893 out of 181
# Fetching page 168...
#   Got 30072 out of 181
# Fetching page 169...
#   Got 30251 out of 181
# Fetching page 170...
#   Got 30430 out of 181
# Fetching page 171...
#   Got 30609 out of 181
# Fetching page 172...
#   Got 30788 out of 181
# Fetching page 173...
#   Got 30967 out of 181
# Fetching page 174...
#   Got 31146 out of 181
# Fetching page 175...
#   Got 31325 out of 181
# Fetching page 176...
#   Got 31504 out of 181
# Fetching page 177...
#   Got 31683 out of 181
# Fetching page 178...
#   Got 31862 out of 181
# Fetching page 179...
#   Got 32041 out of 181
# Fetching page 180...
#   Got 32220 out of 181
# Fetching page 181...
#   Got 32399 out of 181
# Fetching page 182...
#   Got 32578 out of 181
# Fetching page 183...
#   Got 32757 out of 181
# Fetching page 184...
#   Got 32936 out of 181
# Fetching page 185...
#   Got 33115 out of 181
# Fetching page 186...
#   Got 33294 out of 181
# Fetching page 187...
#   Got 33473 out of 181
# Fetching page 188...
#   Got 33652 out of 181
# Fetching page 189...
#   Got 33831 out of 181
# Fetching page 190...
#   Got 34010 out of 181
# Fetching page 191...
#   Got 34189 out of 181
# Fetching page 192...
#   Got 34368 out of 181
# Fetching page 193...
#   Got 34547 out of 181
# Fetching page 194...
#   Got 34726 out of 181
# Fetching page 195...
#   Got 34905 out of 181
# Fetching page 196...
#   Got 35084 out of 181
# Fetching page 197...
#   Got 35263 out of 181
# Fetching page 198...
#   Got 35442 out of 181
# Fetching page 199...
#   Got 35621 out of 181
# Fetching page 200...
#   Got 35800 out of 181
# Fetching page 201...
#   Got 35979 out of 181
# Fetching page 202...
#   Got 36158 out of 181
# Fetching page 203...
#   Got 36337 out of 181
# Fetching page 204...
#   Got 36516 out of 181
# Fetching page 205...
#   Got 36695 out of 181
# Fetching page 206...
#   Got 36874 out of 181
# Fetching page 207...
#   Got 37053 out of 181
# Fetching page 208...
#   Got 37232 out of 181
# Fetching page 209...
#   Got 37411 out of 181
# Fetching page 210...
#   Got 37590 out of 181
# Fetching page 211...
#   Got 37769 out of 181
# Fetching page 212...
#   Got 37948 out of 181
# Fetching page 213...
#   Got 38127 out of 181
# Fetching page 214...
#   Got 38306 out of 181
# Fetching page 215...
#   Got 38485 out of 181
# Fetching page 216...
#   Got 38664 out of 181
# Fetching page 217...
#   Got 38843 out of 181
# Fetching page 218...
#   Got 39022 out of 181
# Fetching page 219...
#   Got 39201 out of 181
# Fetching page 220...
#   Got 39380 out of 181
# Fetching page 221...
#   Got 39559 out of 181
# Fetching page 222...
#   Got 39738 out of 181
# Fetching page 223...
#   Got 39917 out of 181
# Fetching page 224...
#   Got 40096 out of 181
# Fetching page 225...
#   Got 40275 out of 181
# Fetching page 226...
#   Got 40454 out of 181
# Fetching page 227...
#   Got 40633 out of 181
# Fetching page 228...
#   Got 40812 out of 181
# Fetching page 229...
#   Got 40991 out of 181
# Fetching page 230...
#   Got 41170 out of 181
# Fetching page 231...
#   Got 41349 out of 181
# Fetching page 232...
#   Got 41528 out of 181
# Fetching page 233...
#   Got 41707 out of 181
# Fetching page 234...
#   Got 41886 out of 181
# Fetching page 235...
#   Got 42065 out of 181
# Fetching page 236...
#   Got 42244 out of 181
# Fetching page 237...
#   Got 42423 out of 181
# Fetching page 238...
#   Got 42602 out of 181
# Fetching page 239...
#   Got 42781 out of 181
# Fetching page 240...
#   Got 42960 out of 181
# Fetching page 241...
#   Got 43139 out of 181
# Fetching page 242...
#   Got 43318 out of 181
# Fetching page 243...
#   Got 43497 out of 181
# Fetching page 244...
#   Got 43676 out of 181
# Fetching page 245...
#   Got 43855 out of 181
# Fetching page 246...
#   Got 44034 out of 181
# Fetching page 247...
#   Got 44213 out of 181
# Fetching page 248...
#   Got 44392 out of 181
# Fetching page 249...
#   Got 44571 out of 181
# Fetching page 250...
#   Got 44750 out of 181
# Fetching page 251...
#   Got 44929 out of 181
# Fetching page 252...
#   Got 45108 out of 181
# Fetching page 253...
#   Got 45287 out of 181
# Fetching page 254...
#   Got 45466 out of 181
# Fetching page 255...
#   Got 45645 out of 181
# Fetching page 256...
#   Got 45824 out of 181
# Fetching page 257...
#   Got 46003 out of 181
# Fetching page 258...
#   Got 46182 out of 181
# Fetching page 259...
#   Got 46361 out of 181
# Fetching page 260...
#   Got 46540 out of 181
# Fetching page 261...
#   Got 46719 out of 181
# Fetching page 262...
#   Got 46898 out of 181
# Fetching page 263...
#   Got 47077 out of 181
# Fetching page 264...
#   Got 47256 out of 181
# Fetching page 265...
#   Got 47435 out of 181
# Fetching page 266...
#   Got 47614 out of 181
# Fetching page 267...
#   Got 47793 out of 181
# Fetching page 268...
#   Got 47972 out of 181
# Fetching page 269...
#   Got 48151 out of 181
# Fetching page 270...
#   Got 48330 out of 181
# Fetching page 271...
#   Got 48509 out of 181
# Fetching page 272...
#   Got 48688 out of 181
# Fetching page 273...
#   Got 48867 out of 181
# Fetching page 274...
#   Got 49046 out of 181
# Fetching page 275...
#   Got 49225 out of 181
# Fetching page 276...
#   Got 49404 out of 181
# Fetching page 277...
#   Got 49583 out of 181
# Fetching page 278...
#   Got 49762 out of 181
# Fetching page 279...
#   Got 49941 out of 181
# Fetching page 280...
#   Got 50120 out of 181
# Fetching page 281...
#   Got 50299 out of 181
# Fetching page 282...
#   Got 50478 out of 181
# Fetching page 283...
#   Got 50657 out of 181
# Fetching page 284...
#   Got 50836 out of 181
# Fetching page 285...
#   Got 51015 out of 181
# Fetching page 286...
#   Got 51194 out of 181
# Fetching page 287...
#   Got 51373 out of 181
# Fetching page 288...
#   Got 51552 out of 181
# Fetching page 289...
#   Got 51731 out of 181
# Fetching page 290...
#   Got 51910 out of 181
# Fetching page 291...
#   Got 52089 out of 181
# Fetching page 292...
#   Got 52268 out of 181
# Fetching page 293...
#   Got 52447 out of 181
# Fetching page 294...
#   Got 52626 out of 181
# Fetching page 295...
#   Got 52805 out of 181
# Fetching page 296...
#   Got 52984 out of 181
# Fetching page 297...
#   Got 53163 out of 181
# Fetching page 298...
#   Got 53342 out of 181
# Fetching page 299...
#   Got 53521 out of 181
# Fetching page 300...
#   Got 53700 out of 181
# Fetching page 301...
#   Got 53879 out of 181
# Fetching page 302...
#   Got 54058 out of 181
# Fetching page 303...
#   Got 54237 out of 181
# Fetching page 304...
#   Got 54416 out of 181
# Fetching page 305...
#   Got 54595 out of 181
# Fetching page 306...
#   Got 54774 out of 181
# Fetching page 307...
#   Got 54953 out of 181
# Fetching page 308...
#   Got 55132 out of 181
# Fetching page 309...
#   Got 55311 out of 181
# Fetching page 310...
#   Got 55490 out of 181
# Fetching page 311...
#   Got 55669 out of 181
# Fetching page 312...
#   Got 55848 out of 181
# Fetching page 313...
#   Got 56027 out of 181
# Fetching page 314...
#   Got 56206 out of 181
# Fetching page 315...
#   Got 56385 out of 181
# Fetching page 316...
#   Got 56564 out of 181
# Fetching page 317...
#   Got 56743 out of 181
# Fetching page 318...
#   Got 56922 out of 181
# Fetching page 319...
#   Got 57101 out of 181
# Fetching page 320...
#   Got 57280 out of 181
# Fetching page 321...
#   Got 57459 out of 181
# Fetching page 322...
#   Got 57638 out of 181
# Fetching page 323...
#   Got 57817 out of 181
# Fetching page 324...
#   Got 57996 out of 181
# Fetching page 325...
#   Got 58175 out of 181
# Fetching page 326...
#   Got 58354 out of 181
# Fetching page 327...
#   Got 58533 out of 181
# Fetching page 328...
#   Got 58712 out of 181
# Fetching page 329...
#   Got 58891 out of 181
# Fetching page 330...
#   Got 59070 out of 181
# Fetching page 331...
#   Got 59249 out of 181
# Fetching page 332...
#   Got 59428 out of 181
# Fetching page 333...
#   Got 59607 out of 181
# Fetching page 334...
#   Got 59786 out of 181
# Fetching page 335...
#   Got 59965 out of 181
# Fetching page 336...
#   Got 60144 out of 181
# Fetching page 337...
#   Got 60323 out of 181
# Fetching page 338...
#   Got 60502 out of 181
# Fetching page 339...
#   Got 60681 out of 181
# Fetching page 340...
#   Got 60860 out of 181
# Fetching page 341...
#   Got 61039 out of 181
# Fetching page 342...
#   Got 61218 out of 181
# Fetching page 343...
#   Got 61397 out of 181
# Fetching page 344...
#   Got 61576 out of 181
# Fetching page 345...
#   Got 61755 out of 181
# Fetching page 346...
#   Got 61934 out of 181
# Fetching page 347...
#   Got 62113 out of 181
# Fetching page 348...
#   Got 62292 out of 181
# Fetching page 349...
#   Got 62471 out of 181
# Fetching page 350...
#   Got 62650 out of 181
# Fetching page 351...
#   Got 62829 out of 181
# Fetching page 352...
#   Got 63008 out of 181
# Fetching page 353...
#   Got 63187 out of 181
# Fetching page 354...
#   Got 63366 out of 181
# Fetching page 355...
#   Got 63545 out of 181
# Fetching page 356...
#   Got 63724 out of 181
# Fetching page 357...
#   Got 63903 out of 181
# Fetching page 358...
#   Got 64082 out of 181
# Fetching page 359...
#   Got 64261 out of 181
# Fetching page 360...
#   Got 64440 out of 181
# Fetching page 361...
#   Got 64619 out of 181
# Fetching page 362...
#   Got 64798 out of 181
# Fetching page 363...
#   Got 64977 out of 181
# Fetching page 364...
#   Got 65156 out of 181
# Fetching page 365...
#   Got 65335 out of 181
# Fetching page 366...
#   Got 65514 out of 181
# Fetching page 367...
#   Got 65693 out of 181
# Fetching page 368...
#   Got 65872 out of 181
# Fetching page 369...
#   Got 66051 out of 181
# Fetching page 370...
#   Got 66230 out of 181
# Fetching page 371...
#   Got 66409 out of 181
# Fetching page 372...
#   Got 66588 out of 181
# Fetching page 373...
#   Got 66767 out of 181
# Fetching page 374...
#   Got 66946 out of 181
# Fetching page 375...
#   Got 67125 out of 181
# Fetching page 376...
#   Got 67304 out of 181
# Fetching page 377...
#   Got 67483 out of 181
# Fetching page 378...
#   Got 67662 out of 181
# Fetching page 379...
#   Got 67841 out of 181
# Fetching page 380...
#   Got 68020 out of 181
# Fetching page 381...
#   Got 68199 out of 181
# Fetching page 382...
#   Got 68378 out of 181
# Fetching page 383...
#   Got 68557 out of 181
# Fetching page 384...
#   Got 68736 out of 181
# Fetching page 385...
#   Got 68915 out of 181
# Fetching page 386...
#   Got 69094 out of 181
# Fetching page 387...
#   Got 69273 out of 181
# Fetching page 388...
#   Got 69452 out of 181
# Fetching page 389...
#   Got 69631 out of 181
# Fetching page 390...
#   Got 69810 out of 181
# Fetching page 391...
#   Got 69989 out of 181
# Fetching page 392...
#   Got 70168 out of 181
# Fetching page 393...
#   Got 70347 out of 181
# Fetching page 394...
#   Got 70526 out of 181
# Fetching page 395...
#   Got 70705 out of 181
# Fetching page 396...
#   Got 70884 out of 181
# Fetching page 397...
#   Got 71063 out of 181
# Fetching page 398...
#   Got 71242 out of 181
# Fetching page 399...
#   Got 71421 out of 181
# Fetching page 400...
#   Got 71600 out of 181
# Fetching page 401...
#   Got 71779 out of 181
# Fetching page 402...
#   Got 71958 out of 181
# Fetching page 403...
#   Got 72137 out of 181
# Fetching page 404...
#   Got 72316 out of 181
# Fetching page 405...
#   Got 72495 out of 181
# Fetching page 406...
#   Got 72674 out of 181
# Fetching page 407...
#   Got 72853 out of 181
# Fetching page 408...
#   Got 73032 out of 181
# Fetching page 409...
#   Got 73211 out of 181
# Fetching page 410...
#   Got 73390 out of 181
# Fetching page 411...
#   Got 73569 out of 181
# Fetching page 412...
#   Got 73748 out of 181
# Fetching page 413...
#   Got 73927 out of 181
# Fetching page 414...
#   Got 74106 out of 181
# Fetching page 415...
#   Got 74285 out of 181
# Fetching page 416...
#   Got 74464 out of 181
# Fetching page 417...
#   Got 74643 out of 181
# Fetching page 418...
#   Got 74822 out of 181
# Fetching page 419...
#   Got 75001 out of 181
# Fetching page 420...
#   Got 75180 out of 181
# Fetching page 421...
#   Got 75359 out of 181
# Fetching page 422...
#   Got 75538 out of 181
# Fetching page 423...
#   Got 75717 out of 181
# Fetching page 424...
#   Got 75896 out of 181
# Fetching page 425...
#   Got 76075 out of 181
# Fetching page 426...
#   Got 76254 out of 181
# Fetching page 427...
#   Got 76433 out of 181
# Fetching page 428...
#   Got 76612 out of 181
# Fetching page 429...
#   Got 76791 out of 181
# Fetching page 430...
#   Got 76970 out of 181
# Fetching page 431...
#   Got 77149 out of 181
# Fetching page 432...
#   Got 77328 out of 181
# Fetching page 433...
#   Got 77507 out of 181
# Fetching page 434...
#   Got 77686 out of 181
# Fetching page 435...
#   Got 77865 out of 181
# Fetching page 436...
#   Got 78044 out of 181
# Fetching page 437...
#   Got 78223 out of 181
# Fetching page 438...
#   Got 78402 out of 181
# Fetching page 439...
#   Got 78581 out of 181
# Fetching page 440...
#   Got 78760 out of 181
# Fetching page 441...
#   Got 78939 out of 181
# Fetching page 442...
#   Got 79118 out of 181
# Fetching page 443...
#   Got 79297 out of 181
# Fetching page 444...
#   Got 79476 out of 181
# Fetching page 445...
#   Got 79655 out of 181
# Fetching page 446...
#   Got 79834 out of 181
# Fetching page 447...
#   Got 80013 out of 181
# Fetching page 448...
#   Got 80192 out of 181
# Fetching page 449...
#   Got 80371 out of 181
# Fetching page 450...
#   Got 80550 out of 181
# Fetching page 451...
#   Got 80729 out of 181
# Fetching page 452...
#   Got 80908 out of 181
# Fetching page 453...
#   Got 81087 out of 181
# Fetching page 454...
#   Got 81266 out of 181
# Fetching page 455...
#   Got 81445 out of 181
# Fetching page 456...
#   Got 81624 out of 181
# Fetching page 457...
#   Got 81803 out of 181
# Fetching page 458...
#   Got 81982 out of 181
# Fetching page 459...
#   Got 82161 out of 181
# Fetching page 460...
#   Got 82340 out of 181
# Fetching page 461...
#   Got 82519 out of 181
# Fetching page 462...
#   Got 82698 out of 181
# Fetching page 463...
#   Got 82877 out of 181
# Fetching page 464...
#   Got 83056 out of 181
# Fetching page 465...
#   Got 83235 out of 181
# Fetching page 466...
#   Got 83414 out of 181
# Fetching page 467...
#   Got 83593 out of 181
# Fetching page 468...
#   Got 83772 out of 181
# Fetching page 469...
#   Got 83951 out of 181
# Fetching page 470...
#   Got 84130 out of 181
# Fetching page 471...
#   Got 84309 out of 181
# Fetching page 472...
#   Got 84488 out of 181
# Fetching page 473...
#   Got 84667 out of 181
# Fetching page 474...
#   Got 84846 out of 181
# Fetching page 475...
#   Got 85025 out of 181
# Fetching page 476...
#   Got 85204 out of 181
# Fetching page 477...
#   Got 85383 out of 181
# Fetching page 478...
#   Got 85562 out of 181
# Fetching page 479...
#   Got 85741 out of 181
# Fetching page 480...
#   Got 85920 out of 181
# Fetching page 481...
#   Got 86099 out of 181
# Fetching page 482...
#   Got 86278 out of 181
# Fetching page 483...
#   Got 86457 out of 181
# Fetching page 484...
#   Got 86636 out of 181
# Fetching page 485...
#   Got 86815 out of 181
# Fetching page 486...
#   Got 86994 out of 181
# Fetching page 487...
#   Got 87173 out of 181
# Fetching page 488...
#   Got 87352 out of 181
# Fetching page 489...
#   Got 87531 out of 181
# Fetching page 490...
#   Got 87710 out of 181
# Fetching page 491...
#   Got 87889 out of 181
# Fetching page 492...
#   Got 88068 out of 181
# Fetching page 493...
#   Got 88247 out of 181
# Fetching page 494...
#   Got 88426 out of 181
# Fetching page 495...
#   Got 88605 out of 181
# Fetching page 496...
#   Got 88784 out of 181
# Fetching page 497...
#   Got 88963 out of 181
# Fetching page 498...
#   Got 89142 out of 181
# Fetching page 499...
#   Got 89321 out of 181
# Fetching page 500...
#   Got 89500 out of 181
# Fetching page 501...
#   Got 89679 out of 181
# Fetching page 502...
#   Got 89858 out of 181
# Fetching page 503...
#   Got 90037 out of 181
# Fetching page 504...
#   Got 90216 out of 181
# Fetching page 505...
#   Got 90395 out of 181
# Fetching page 506...
#   Got 90574 out of 181
# Fetching page 507...
#   Got 90753 out of 181
# Fetching page 508...
#   Got 90932 out of 181
# Fetching page 509...
#   Got 91111 out of 181
# Fetching page 510...
#   Got 91290 out of 181
# Fetching page 511...
#   Got 91469 out of 181
# Fetching page 512...
#   Got 91648 out of 181
# Fetching page 513...
#   Got 91827 out of 181
# Fetching page 514...
#   Got 92006 out of 181
# Fetching page 515...
#   Got 92185 out of 181
# Fetching page 516...
#   Got 92364 out of 181
# Fetching page 517...
#   Got 92543 out of 181
# ...
# Fetching page 823...
#   Got 147317 out of 181
# Fetching page 824...
#   Got 147496 out of 181
# Fetching page 825...
#   Got 147675 out of 181
# Fetching page 826...
#   Got 147854 out of 181
# Fetching page 827...
#   Got 148033 out of 181
# Fetching page 828...
#   Got 148212 out of 181
# Fetching page 829...
#   Got 148391 out of 181
# Fetching page 830...
#   Got 148570 out of 181
# Fetching page 831...
#   Got 148749 out of 181
# Fetching page 832...
#   Got 148928 out of 181
# Fetching page 833...
#   Got 149107 out of 181
# Fetching page 834...
#   Got 149286 out of 181
# Fetching page 835...
#   Got 149465 out of 181
# Fetching page 836...
#   Got 149644 out of 181
# Fetching page 837...
#   Got 149823 out of 181
# Fetching page 838...
#   Got 150002 out of 181
# Fetching page 839...
#   Got 150181 out of 181
# Fetching page 840...
#   Got 150360 out of 181
# Fetching page 841...
#   Got 150539 out of 181
# Fetching page 842...
#   Got 150718 out of 181
# Fetching page 843...
#   Got 150897 out of 181
# Fetching page 844...
#   Got 151076 out of 181
# Fetching page 845...
#   Got 151255 out of 181
# Fetching page 846...
#   Got 151434 out of 181
# Fetching page 847...
#   Got 151613 out of 181
# Fetching page 848...
#   Got 151792 out of 181
# Fetching page 849...
#   Got 151971 out of 181
# Fetching page 850...
#   Got 152150 out of 181
# Fetching page 851...
#   Got 152329 out of 181
# Fetching page 852...
#   Got 152508 out of 181
# Fetching page 853...
#   Got 152687 out of 181
# Fetching page 854...
#   Got 152866 out of 181
# Fetching page 855...
#   Got 153045 out of 181
# Fetching page 856...
#   Got 153224 out of 181
# Fetching page 857...
#   Got 153403 out of 181
# Fetching page 858...
#   Got 153582 out of 181
# Fetching page 859...
#   Got 153761 out of 181
# Fetching page 860...
#   Got 153940 out of 181
# Fetching page 861...
#   Got 154119 out of 181
# Fetching page 862...
#   Got 154298 out of 181
# Fetching page 863...
#   Got 154477 out of 181
# Fetching page 864...
#   Got 154656 out of 181
# Fetching page 865...
#   Got 154835 out of 181
# Fetching page 866...
#   Got 155014 out of 181
# Fetching page 867...
#   Got 155193 out of 181
# Fetching page 868...
#   Got 155372 out of 181
# Fetching page 869...
#   Got 155551 out of 181
# Fetching page 870...
#   Got 155730 out of 181
# Fetching page 871...
#   Got 155909 out of 181
# Fetching page 872...
#   Got 156088 out of 181
# Fetching page 873...
#   Got 156267 out of 181
# Fetching page 874...
#   Got 156446 out of 181
# Fetching page 875...
#   Got 156625 out of 181
# Fetching page 876...
#   Got 156804 out of 181
# Fetching page 877...
#   Got 156983 out of 181
# Fetching page 878...
#   Got 157162 out of 181
# Fetching page 879...
#   Got 157341 out of 181
# Fetching page 880...
#   Got 157520 out of 181
# Fetching page 881...
#   Got 157699 out of 181
# Fetching page 882...
#   Got 157878 out of 181
# Fetching page 883...
#   Got 158057 out of 181
# Fetching page 884...
#   Got 158236 out of 181
# Fetching page 885...
#   Got 158415 out of 181
# Fetching page 886...
#   Got 158594 out of 181
# Fetching page 887...
#   Got 158773 out of 181
# Fetching page 888...
#   Got 158952 out of 181
# Fetching page 889...
#   Got 159131 out of 181
# Fetching page 890...
#   Got 159310 out of 181
# Fetching page 891...
#   Got 159489 out of 181
# Fetching page 892...
#   Got 159668 out of 181
# Fetching page 893...
#   Got 159847 out of 181
# Fetching page 894...
#   Got 160026 out of 181
# Fetching page 895...
#   Got 160205 out of 181
# Fetching page 896...
#   Got 160384 out of 181
# Fetching page 897...
#   Got 160563 out of 181
# Fetching page 898...
#   Got 160742 out of 181
# Fetching page 899...
#   Got 160921 out of 181
# Fetching page 900...
#   Got 161100 out of 181
# Fetching page 901...
#   Got 161279 out of 181
# Fetching page 902...
#   Got 161458 out of 181
# Fetching page 903...
#   Got 161637 out of 181
# Fetching page 904...
#   Got 161816 out of 181
# Fetching page 905...
#   Got 161995 out of 181
# Fetching page 906...
#   Got 162174 out of 181
# Fetching page 907...
#   Got 162353 out of 181
# Fetching page 908...
#   Got 162532 out of 181
# Fetching page 909...
#   Got 162711 out of 181
# Fetching page 910...
#   Got 162890 out of 181
# Fetching page 911...
#   Got 163069 out of 181
# Fetching page 912...
#   Got 163248 out of 181
# Fetching page 913...
#   Got 163427 out of 181
# Fetching page 914...
#   Got 163606 out of 181
# Fetching page 915...
#   Got 163785 out of 181
# Fetching page 916...
#   Got 163964 out of 181
# Fetching page 917...
#   Got 164143 out of 181
# Fetching page 918...
#   Got 164322 out of 181
# Fetching page 919...
#   Got 164501 out of 181
# Fetching page 920...
#   Got 164680 out of 181
# Fetching page 921...
#   Got 164859 out of 181
# Fetching page 922...
#   Got 165038 out of 181
# Fetching page 923...
#   Got 165217 out of 181
# Fetching page 924...
#   Got 165396 out of 181
# Fetching page 925...
#   Got 165575 out of 181
# Fetching page 926...
#   Got 165754 out of 181
# Fetching page 927...
#   Got 165933 out of 181
# Fetching page 928...
#   Got 166112 out of 181
# Fetching page 929...
#   Got 166291 out of 181
# Fetching page 930...
#   Got 166470 out of 181
# Fetching page 931...
#   Got 166649 out of 181
# Fetching page 932...
#   Got 166828 out of 181
# Fetching page 933...
#   Got 167007 out of 181
# Fetching page 934...
#   Got 167186 out of 181
# Fetching page 935...
#   Got 167365 out of 181
# Fetching page 936...
#   Got 167544 out of 181
# Fetching page 937...
#   Got 167723 out of 181
# Fetching page 938...
#   Got 167902 out of 181
# Fetching page 939...
#   Got 168081 out of 181
# Fetching page 940...
#   Got 168260 out of 181
# Fetching page 941...
#   Got 168439 out of 181
# Fetching page 942...
#   Got 168618 out of 181
# Fetching page 943...
#   Got 168797 out of 181
# Fetching page 944...
#   Got 168976 out of 181
# Fetching page 945...
#   Got 169155 out of 181
# Fetching page 946...
#   Got 169334 out of 181
# Fetching page 947...
#   Got 169513 out of 181
# Fetching page 948...
#   Got 169692 out of 181
# Fetching page 949...
#   Got 169871 out of 181
# Fetching page 950...
#   Got 170050 out of 181
# Fetching page 951...
#   Got 170229 out of 181
# Fetching page 952...
#   Got 170408 out of 181
# Fetching page 953...
#   Got 170587 out of 181
# Fetching page 954...
#   Got 170766 out of 181
# Fetching page 955...
#   Got 170945 out of 181
# Fetching page 956...
#   Got 171124 out of 181
# Fetching page 957...
#   Got 171303 out of 181
# Fetching page 958...
#   Got 171482 out of 181
# Fetching page 959...
#   Got 171661 out of 181
# Fetching page 960...
#   Got 171840 out of 181
# Fetching page 961...
#   Got 172019 out of 181
# Fetching page 962...
#   Got 172198 out of 181
# Fetching page 963...
#   Got 172377 out of 181
# Fetching page 964...
#   Got 172556 out of 181
# Fetching page 965...
#   Got 172735 out of 181
# Fetching page 966...
#   Got 172914 out of 181
# Fetching page 967...
#   Got 173093 out of 181
# Fetching page 968...
#   Got 173272 out of 181
# Fetching page 969...
#   Got 173451 out of 181
# Fetching page 970...
#   Got 173630 out of 181
# Fetching page 971...
#   Got 173809 out of 181
# Fetching page 972...
#   Got 173988 out of 181
# Fetching page 973...
#   Got 174167 out of 181
# Fetching page 974...
#   Got 174346 out of 181
# Fetching page 975...
#   Got 174525 out of 181
# Fetching page 976...
#   Got 174704 out of 181
# Fetching page 977...
#   Got 174883 out of 181
# Fetching page 978...
#   Got 175062 out of 181
# Fetching page 979...
#   Got 175241 out of 181
# Fetching page 980...
#   Got 175420 out of 181
# Fetching page 981...
#   Got 175599 out of 181
# Fetching page 982...
#   Got 175778 out of 181
# Fetching page 983...
#   Got 175957 out of 181
# Fetching page 984...
#   Got 176136 out of 181
# Fetching page 985...
#   Got 176315 out of 181
# Fetching page 986...
#   Got 176494 out of 181
# Fetching page 987...
#   Got 176673 out of 181
# Fetching page 988...
#   Got 176852 out of 181
# Fetching page 989...
#   Got 177031 out of 181
# Fetching page 990...
#   Got 177210 out of 181
# Fetching page 991...
#   Got 177389 out of 181
# Fetching page 992...
#   Got 177568 out of 181
# Fetching page 993...
#   Got 177747 out of 181
# Fetching page 994...
#   Got 177926 out of 181
# Fetching page 995...
#   Got 178105 out of 181
# Fetching page 996...
#   Got 178284 out of 181
# Fetching page 997...
#   Got 178463 out of 181
# Fetching page 998...
#   Got 178642 out of 181
# Fetching page 999...
#   Got 178821 out of 181
# Fetching page 1000...
#   Got 179000 out of 181
# Fetching page 1001...
#   Got 179179 out of 181
# Fetching page 1002...
#   Got 179358 out of 181
# Fetching page 1003...
#   Got 179537 out of 181
# Fetching page 1004...
#   Got 179716 out of 181
# Fetching page 1005...
#   Got 179895 out of 181
# Fetching page 1006...
#   Got 180074 out of 181
# Fetching page 1007...
#   Got 180253 out of 181
# Fetching page 1008...
#   Got 180432 out of 181
# Fetching page 1009...
#   Got 180611 out of 181
# Fetching page 1010...
#   Got 180790 out of 181
# Fetching page 1011...
#   Got 180969 out of 181
# Fetching page 1012...
#   Got 181148 out of 181
# Fetching page 1013...
#   Got 181327 out of 181
# Fetching page 1014...
#   Got 181506 out of 181
# Fetching page 1015...
#   Got 181685 out of 181
# Fetching page 1016...
#   Got 181864 out of 181
# Fetching page 1017...
#   Got 182043 out of 181
# Fetching page 1018...
#   Got 182222 out of 181
# Fetching page 1019...
#   Got 182401 out of 181
# Fetching page 1020...
#   Got 182580 out of 181
# Fetching page 1021...
#   Got 182759 out of 181
# Fetching page 1022...
#   Got 182938 out of 181
# Fetching page 1023...
#   Got 183117 out of 181
# Fetching page 1024...
#   Got 183296 out of 181
# Fetching page 1025...
#   Got 183475 out of 181
# Fetching page 1026...
#   Got 183654 out of 181
# Fetching page 1027...
#   Got 183833 out of 181
# Fetching page 1028...
#   Got 184012 out of 181
# Fetching page 1029...
#   Got 184191 out of 181
# Fetching page 1030...
#   Got 184370 out of 181
# Fetching page 1031...
#   Got 184549 out of 181
# Fetching page 1032...
#   Got 184728 out of 181
# Fetching page 1033...
#   Got 184907 out of 181
# Fetching page 1034...
#   Got 185086 out of 181
# Fetching page 1035...
#   Got 185265 out of 181
# Fetching page 1036...
#   Got 185444 out of 181
# Fetching page 1037...
#   Got 185623 out of 181
# Fetching page 1038...
#   Got 185802 out of 181
# Fetching page 1039...
#   Got 185981 out of 181
# Fetching page 1040...
#   Got 186160 out of 181
# Fetching page 1041...
#   Got 186339 out of 181
# Fetching page 1042...
#   Got 186518 out of 181
# Fetching page 1043...
#   Got 186697 out of 181
# Fetching page 1044...
#   Got 186876 out of 181
# Fetching page 1045...
#   Got 187055 out of 181
# Fetching page 1046...
#   Got 187234 out of 181
# Fetching page 1047...
#   Got 187413 out of 181
# Fetching page 1048...
#   Got 187592 out of 181
# Fetching page 1049...
#   Got 187771 out of 181
# Fetching page 1050...
#   Got 187950 out of 181
# Fetching page 1051...
#   Got 188129 out of 181
# Fetching page 1052...
#   Got 188308 out of 181
# Fetching page 1053...
#   Got 188487 out of 181
# Fetching page 1054...
#   Got 188666 out of 181
# Fetching page 1055...
#   Got 188845 out of 181
# Fetching page 1056...
#   Got 189024 out of 181
# Fetching page 1057...
#   Got 189203 out of 181
# Fetching page 1058...
#   Got 189382 out of 181
# Fetching page 1059...
#   Got 189561 out of 181
# Fetching page 1060...
#   Got 189740 out of 181
# Fetching page 1061...
#   Got 189919 out of 181
# Fetching page 1062...
#   Got 190098 out of 181
# Fetching page 1063...
#   Got 190277 out of 181
# Fetching page 1064...
#   Got 190456 out of 181
# Fetching page 1065...
#   Got 190635 out of 181
# Fetching page 1066...
#   Got 190814 out of 181
# Fetching page 1067...
#   Got 190993 out of 181
# Fetching page 1068...
#   Got 191172 out of 181
# Fetching page 1069...
#   Got 191351 out of 181
# Fetching page 1070...
#   Got 191530 out of 181
# Fetching page 1071...
#   Got 191709 out of 181
# Fetching page 1072...
#   Got 191888 out of 181
# Fetching page 1073...
#   Got 192067 out of 181
# Fetching page 1074...
#   Got 192246 out of 181
# Fetching page 1075...
#   Got 192425 out of 181
# Fetching page 1076...
#   Got 192604 out of 181
# Fetching page 1077...
#   Got 192783 out of 181
# Fetching page 1078...
#   Got 192962 out of 181
# Fetching page 1079...
#   Got 193141 out of 181
# Fetching page 1080...
#   Got 193320 out of 181
# Fetching page 1081...
#   Got 193499 out of 181
# Fetching page 1082...
#   Got 193678 out of 181
# Fetching page 1083...
#   Got 193857 out of 181
# Fetching page 1084...
#   Got 194036 out of 181
# Fetching page 1085...
#   Got 194215 out of 181
# Fetching page 1086...
#   Got 194394 out of 181
# Fetching page 1087...
#   Got 194573 out of 181
# Fetching page 1088...
#   Got 194752 out of 181
# Fetching page 1089...
#   Got 194931 out of 181
# Fetching page 1090...
#   Got 195110 out of 181
# Fetching page 1091...
#   Got 195289 out of 181
# Fetching page 1092...
#   Got 195468 out of 181
# Fetching page 1093...
#   Got 195647 out of 181
# Fetching page 1094...
#   Got 195826 out of 181
# Fetching page 1095...
#   Got 196005 out of 181
# Fetching page 1096...
#   Got 196184 out of 181
# Fetching page 1097...
#   Got 196363 out of 181
# Fetching page 1098...
#   Got 196542 out of 181
# Fetching page 1099...
#   Got 196721 out of 181
# Fetching page 1100...
#   Got 196900 out of 181
# Fetching page 1101...
#   Got 197079 out of 181
# Fetching page 1102...
# Error fetching tags: Response ended prematurely
# Saved 197079 items to groundhogg_exports/tags.csv
# Fetching broadcasts...
# Fetching page 1...
#   Got 248 out of 281
# Fetching page 2...
#   Got 496 out of 281
# Fetching page 3...
#   Got 744 out of 281
# Fetching page 4...
#   Got 992 out of 281
# Fetching page 5...
#   Got 1240 out of 281
# Fetching page 6...
#   Got 1488 out of 281
# Fetching page 7...
#   Got 1736 out of 281
# Fetching page 8...
#   Got 1984 out of 281
# Fetching page 9...
#   Got 2232 out of 281
# Fetching page 10...
#   Got 2480 out of 281
# Fetching page 11...
#   Got 2728 out of 281
# Fetching page 12...
#   Got 2976 out of 281
# Fetching page 13...
#   Got 3224 out of 281
# Fetching page 14...
#   Got 3472 out of 281
# Fetching page 15...
#   Got 3720 out of 281
# Fetching page 16...
#   Got 3968 out of 281
# Fetching page 17...
#   Got 4216 out of 281
# Fetching page 18...
#   Got 4464 out of 281
# Fetching page 19...
#   Got 4712 out of 281
# Fetching page 20...
#   Got 4960 out of 281
# Fetching page 21...
#   Got 5208 out of 281
# Fetching page 22...
#   Got 5456 out of 281
# Fetching page 23...
#   Got 5704 out of 281
# Fetching page 24...
#   Got 5952 out of 281
# Fetching page 25...
#   Got 6200 out of 281
# Fetching page 26...
#   Got 6448 out of 281
# Fetching page 27...
#   Got 6696 out of 281
# Fetching page 28...
#   Got 6944 out of 281
# Fetching page 29...
#   Got 7192 out of 281
# Fetching page 30...
#   Got 7440 out of 281
# Fetching page 31...
#   Got 7688 out of 281
# Fetching page 32...
#   Got 7936 out of 281
# Fetching page 33...
#   Got 8184 out of 281
# Fetching page 34...
#   Got 8432 out of 281
# Fetching page 35...
#   Got 8680 out of 281
# Fetching page 36...
#   Got 8928 out of 281
# Fetching page 37...
#   Got 9176 out of 281
# Fetching page 38...
#   Got 9424 out of 281
# Fetching page 39...
#   Got 9672 out of 281
# Fetching page 40...
#   Got 9920 out of 281
# Fetching page 41...
#   Got 10168 out of 281
# Fetching page 42...
#   Got 10416 out of 281
# Fetching page 43...
#   Got 10664 out of 281
# Fetching page 44...
#   Got 10912 out of 281
# Fetching page 45...
#   Got 11160 out of 281
# Fetching page 46...
#   Got 11408 out of 281
# Fetching page 47...
#   Got 11656 out of 281
# Fetching page 48...
#   Got 11904 out of 281
# Fetching page 49...
#   Got 12152 out of 281
# Fetching page 50...
#   Got 12400 out of 281
# Fetching page 51...
#   Got 12648 out of 281
# Fetching page 52...
#   Got 12896 out of 281
# Fetching page 53...
#   Got 13144 out of 281
# Fetching page 54...
#   Got 13392 out of 281
# Fetching page 55...
#   Got 13640 out of 281
# Fetching page 56...
#   Got 13888 out of 281
# Fetching page 57...
#   Got 14136 out of 281
# Fetching page 58...
# Error fetching broadcasts: Response ended prematurely
# Saved 14136 items to groundhogg_exports/broadcasts.csv
# Fetching emails...
# Fetching page 1...
#   Got 489 out of 489
# Fetching page 2...
#   Got 978 out of 489
# Fetching page 3...
#   Got 1467 out of 489
# Fetching page 4...
#   Got 1956 out of 489
# Fetching page 5...
#   Got 2445 out of 489
# Fetching page 6...
#   Got 2934 out of 489
# Fetching page 7...
#   Got 3423 out of 489
# Fetching page 8...
#   Got 3912 out of 489
# Fetching page 9...
#   Got 4401 out of 489
# Fetching page 10...
#   Got 4890 out of 489
# Fetching page 11...
# Error fetching emails: Response ended prematurely
# Saved 4890 items to groundhogg_exports/emails.csv
# Fetching sms...
# Fetching page 1...
#   Got 23 out of 23
# Saved 23 items to groundhogg_exports/sms.csv
# Data export completed!
